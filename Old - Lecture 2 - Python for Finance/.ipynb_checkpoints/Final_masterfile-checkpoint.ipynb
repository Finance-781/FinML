# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Importing-data" data-toc-modified-id="Importing-data-1" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Importing data</a></div><div class="lev1 toc-item"><a href="#Regressions" data-toc-modified-id="Regressions-2" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">2&nbsp;&nbsp;</span>Regressions</a></div><div class="lev2 toc-item"><a href="#Data-Prep" data-toc-modified-id="Data-Prep-21" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Data Prep</a></div><div class="lev2 toc-item"><a href="#Data-prep" data-toc-modified-id="Data-prep-22" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Data prep</a></div><div class="lev2 toc-item"><a href="#CAPM" data-toc-modified-id="CAPM-23" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>CAPM</a></div><div class="lev3 toc-item"><a href="#CAPM-Plot" data-toc-modified-id="CAPM-Plot-231" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>CAPM Plot</a></div><div class="lev2 toc-item"><a href="#Fama-French" data-toc-modified-id="Fama-French-24" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Fama French</a></div><div class="lev2 toc-item"><a href="#Carhart" data-toc-modified-id="Carhart-25" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Carhart</a></div><div class="lev1 toc-item"><a href="#Risk-Measures" data-toc-modified-id="Risk-Measures-3" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3&nbsp;&nbsp;</span>Risk Measures</a></div><div class="lev2 toc-item"><a href="#Test-Statistics" data-toc-modified-id="Test-Statistics-31" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Test Statistics</a></div><div class="lev2 toc-item"><a href="#Maximum-Drawdown" data-toc-modified-id="Maximum-Drawdown-32" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Maximum Drawdown</a></div><div class="lev2 toc-item"><a href="#VaR-and-Expected-Shortfall" data-toc-modified-id="VaR-and-Expected-Shortfall-33" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>VaR and Expected Shortfall</a></div><div class="lev2 toc-item"><a href="#Portfolio-Turnover" data-toc-modified-id="Portfolio-Turnover-34" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Portfolio Turnover</a></div><div class="lev2 toc-item"><a href="#Skewness-and-Kurtosis" data-toc-modified-id="Skewness-and-Kurtosis-35" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Skewness and Kurtosis</a></div><div class="lev3 toc-item"><a href="#Jarque-Bera" data-toc-modified-id="Jarque-Bera-351" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Jarque-Bera</a></div><div class="lev2 toc-item"><a href="#Corr,-Variance,-STD,-SV-and-SSD" data-toc-modified-id="Corr,-Variance,-STD,-SV-and-SSD-36" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Corr, Variance, STD, SV and SSD</a></div><div class="lev3 toc-item"><a href="#Correlation" data-toc-modified-id="Correlation-361" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Correlation</a></div><div class="lev3 toc-item"><a href="#Variance" data-toc-modified-id="Variance-362" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span>Variance</a></div><div class="lev3 toc-item"><a href="#Semi-Variance-and-Semi-Standard-Deviation" data-toc-modified-id="Semi-Variance-and-Semi-Standard-Deviation-363" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.6.3&nbsp;&nbsp;</span>Semi-Variance and Semi-Standard Deviation</a></div><div class="lev2 toc-item"><a href="#Relative-Risk-Measures" data-toc-modified-id="Relative-Risk-Measures-37" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Relative Risk Measures</a></div><div class="lev3 toc-item"><a href="#Sharpe:" data-toc-modified-id="Sharpe:-371" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.7.1&nbsp;&nbsp;</span>Sharpe:</a></div><div class="lev3 toc-item"><a href="#RAPA" data-toc-modified-id="RAPA-372" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.7.2&nbsp;&nbsp;</span>RAPA</a></div><div class="lev3 toc-item"><a href="#Treynor:" data-toc-modified-id="Treynor:-373" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.7.3&nbsp;&nbsp;</span>Treynor:</a></div><div class="lev3 toc-item"><a href="#Sortino:" data-toc-modified-id="Sortino:-374" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.7.4&nbsp;&nbsp;</span>Sortino:</a></div><div class="lev3 toc-item"><a href="#Probability-of-Shortfall-and-Return-on-Probability-of-Shortfall" data-toc-modified-id="Probability-of-Shortfall-and-Return-on-Probability-of-Shortfall-375" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.7.5&nbsp;&nbsp;</span>Probability of Shortfall and Return on Probability of Shortfall</a></div><div class="lev2 toc-item"><a href="#Summary" data-toc-modified-id="Summary-38" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Summary</a></div><div class="lev1 toc-item"><a href="#Plots" data-toc-modified-id="Plots-4" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">4&nbsp;&nbsp;</span>Plots</a></div><div class="lev2 toc-item"><a href="#Portfolio-values" data-toc-modified-id="Portfolio-values-41" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Portfolio values</a></div><div class="lev2 toc-item"><a href="#Bar-plot-for-excess-return" data-toc-modified-id="Bar-plot-for-excess-return-42" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Bar plot for excess return</a></div><div class="lev2 toc-item"><a href="#FTSE-100-Histogram" data-toc-modified-id="FTSE-100-Histogram-43" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>FTSE 100 Histogram</a></div><div class="lev2 toc-item"><a href="#DoD-Histogram" data-toc-modified-id="DoD-Histogram-44" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>DoD Histogram</a></div><div class="lev2 toc-item"><a href="#Rolling-STD" data-toc-modified-id="Rolling-STD-45" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Rolling STD</a></div><div class="lev2 toc-item"><a href="#Rolling-std2" data-toc-modified-id="Rolling-std2-46" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Rolling std2</a></div><div class="lev2 toc-item"><a href="#Max-Drawdown-plot" data-toc-modified-id="Max-Drawdown-plot-47" data-vivaldi-spatnav-clickable="1"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Max Drawdown plot</a></div>

# %%
# %matplotlib inline
#%% Preamp
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" # For reference, the options for that are 'all', 'none', 'last' and 'last_expr'

import seaborn as sns
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:,.5f}'.format

import matplotlib.pyplot as plt
from matplotlib import style
style.use('seaborn-whitegrid')
#print(plt.style.available)
import matplotlib.ticker as mtick
import matplotlib.dates as mdates
import matplotlib.mlab as mlab
from matplotlib.ticker import FuncFormatter

import statsmodels.api as sm

import statsmodels.tools

from scipy import stats
import time
# Out:
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# # Importing data

# %%
universe
# Out:
# {'0': 0                              3i Group PLC
#  1                  Alliance & Leicester Ltd
#  2               Alliance Boots Holdings Ltd
#  3                         Allied Domecq Ltd
#  4                        Anglo American PLC
#  5                          ARM Holdings PLC
#  6              Associated British Foods PLC
#  7                           AstraZeneca PLC
#  8                                 Aviva PLC
#  9                           BAE Systems PLC
#  10                             Barclays PLC
#  11                             BG Group Ltd
#  12                         BHP Billiton PLC
#  13                       BIP Industries Ltd
#  14                        BOC Group Ltd/The
#  15                                   BP PLC
#  16             British American Tobacco PLC
#  17                  British Land Co PLC/The
#  18                             BT Group PLC
#  19      Cable & Wireless Communications Ltd
#  20                              Cadbury Ltd
#  21                   Canary Wharf Group PLC
#  22                               Capita PLC
#  23                             Carnival PLC
#  24                       Celltech Group Ltd
#  25                             Centrica PLC
#  26                        Compass Group PLC
#  27           Daily Mail & General Trust PLC
#  28                               Diageo PLC
#  29                  Dixons Retail Group Ltd
#                         ...
#  69                            Rio Tinto PLC
#  70                 Rolls-Royce Holdings PLC
#  71         Royal Bank of Scotland Group PLC
#  72                  RSA Insurance Group PLC
#  73                            SABMiller PLC
#  74                              Safeway Ltd
#  75                       Sage Group PLC/The
#  76                         Santander UK PLC
#  77                            Schroders PLC
#  78                 Scottish & Newcastle Ltd
#  79                       Scottish Power Ltd
#  80                         Severn Trent PLC
#  81     Shell Transport & Trading Co Ltd/The
#  82                                Shire PLC
#  83                       Six Continents Ltd
#  84                                  Sky PLC
#  85                       Smith & Nephew PLC
#  86                         Smiths Group PLC
#  87                                  SSE PLC
#  88                   Standard Chartered PLC
#  89                    Telefonica Europe PLC
#  90                                Tesco PLC
#  91                   Thomson Reuters UK Ltd
#  92                             Unilever PLC
#  93               United Utilities Group PLC
#  94                       Vodafone Group PLC
#  95             Wm Morrison Supermarkets PLC
#  96                             Wolseley PLC
#  97                                  WPP PLC
#  101                               UKX Index
#  Name: 01/01/2002, Length: 99, dtype: object,
#  '1': 0                              3i Group PLC
#  1                  Alliance & Leicester Ltd
#  2               Alliance Boots Holdings Ltd
#  3                      Alliance UniChem PLC
#  4                         Allied Domecq Ltd
#  5                        Anglo American PLC
#  6                       Ascential Group Ltd
#  7              Associated British Foods PLC
#  8                           AstraZeneca PLC
#  9                                 Aviva PLC
#  10                          BAE Systems PLC
#  11                             Barclays PLC
#  12                             BG Group Ltd
#  13                         BHP Billiton PLC
#  14                        BOC Group Ltd/The
#  15                                   BP PLC
#  16                   Bradford & Bingley PLC
#  17             British American Tobacco PLC
#  18                  British Land Co PLC/The
#  19                             BT Group PLC
#  20                                Bunzl PLC
#  21                              Cadbury Ltd
#  22                   Canary Wharf Group PLC
#  23                               Capita PLC
#  24                             Carnival PLC
#  25                             Centrica PLC
#  26                        Compass Group PLC
#  27           Daily Mail & General Trust PLC
#  28                               Diageo PLC
#  29                  Dixons Retail Group Ltd
#                         ...
#  71         Royal Bank of Scotland Group PLC
#  72                  RSA Insurance Group PLC
#  73                            SABMiller PLC
#  74                              Safeway Ltd
#  75                       Sage Group PLC/The
#  76                         Santander UK PLC
#  77                            Schroders PLC
#  78                 Scottish & Newcastle Ltd
#  79                       Scottish Power Ltd
#  80                         Severn Trent PLC
#  81     Shell Transport & Trading Co Ltd/The
#  82                                Shire PLC
#  83                       Six Continents Ltd
#  84                                  Sky PLC
#  85                       Smith & Nephew PLC
#  86                         Smiths Group PLC
#  87                                  SSE PLC
#  88                   Standard Chartered PLC
#  89                    Telefonica Europe PLC
#  90                                Tesco PLC
#  91                   Thomson Reuters UK Ltd
#  92                             Unilever PLC
#  93               United Utilities Group PLC
#  94                       Vodafone Group PLC
#  95                            Whitbread PLC
#  96             Wm Morrison Supermarkets PLC
#  97                             Wolseley PLC
#  98                                  WPP PLC
#  99                              Xstrata Ltd
#  101                               UKX Index
#  Name: 01/01/2003, Length: 101, dtype: object,
#  '10': 0                        Admiral Group PLC
#  1                              Aggreko PLC
#  2                  Amec Foster Wheeler PLC
#  3                       Anglo American PLC
#  4                          Antofagasta PLC
#  5                         ARM Holdings PLC
#  6                        Ashmore Group PLC
#  7             Associated British Foods PLC
#  8                          AstraZeneca PLC
#  9                                Aviva PLC
#  10                         BAE Systems PLC
#  11                            Barclays PLC
#  12                            BG Group Ltd
#  13                        BHP Billiton PLC
#  14                                  BP PLC
#  15            British American Tobacco PLC
#  16                 British Land Co PLC/The
#  17                            BT Group PLC
#  18                               Bunzl PLC
#  19                      Burberry Group PLC
#  20                        Cairn Energy PLC
#  21                              Capita PLC
#  22                            Carnival PLC
#  23                            Centrica PLC
#  24                       Compass Group PLC
#  25                                 CRH PLC
#  26                              Diageo PLC
#  27                        Essar Energy Ltd
#  28     Eurasian Natural Resources Corp Ltd
#  29                               Evraz PLC
#                        ...
#  71                Rolls-Royce Holdings PLC
#  72        Royal Bank of Scotland Group PLC
#  73                   Royal Dutch Shell PLC
#  74                 RSA Insurance Group PLC
#  75                           SABMiller PLC
#  76                      Sage Group PLC/The
#  77                           Schroders PLC
#  78                         Serco Group PLC
#  79                        Severn Trent PLC
#  80                               Shire PLC
#  81                                 Sky PLC
#  82                      Smith & Nephew PLC
#  83                        Smiths Group PLC
#  84                                 SSE PLC
#  85                  Standard Chartered PLC
#  86                       Standard Life PLC
#  87                         Tate & Lyle PLC
#  88                               Tesco PLC
#  89                          Tullow Oil PLC
#  90                            Unilever PLC
#  91              United Utilities Group PLC
#  92                   Vedanta Resources PLC
#  93                      Vodafone Group PLC
#  94                      Weir Group PLC/The
#  95                           Whitbread PLC
#  96            Wm Morrison Supermarkets PLC
#  97                            Wolseley PLC
#  98                                 WPP PLC
#  99                             Xstrata Ltd
#  101                              UKX Index
#  Name: 01/01/2012, Length: 101, dtype: object,
#  '11': 0            Aberdeen Asset Management PLC
#  1                        Admiral Group PLC
#  2                              Aggreko PLC
#  3                  Amec Foster Wheeler PLC
#  4                       Anglo American PLC
#  5                          Antofagasta PLC
#  6                         ARM Holdings PLC
#  7             Associated British Foods PLC
#  8                          AstraZeneca PLC
#  9                                Aviva PLC
#  10         Babcock International Group PLC
#  11                         BAE Systems PLC
#  12                            Barclays PLC
#  13                            BG Group Ltd
#  14                        BHP Billiton PLC
#  15                                  BP PLC
#  16            British American Tobacco PLC
#  17                 British Land Co PLC/The
#  18                            BT Group PLC
#  19                               Bunzl PLC
#  20                      Burberry Group PLC
#  21                              Capita PLC
#  22                            Carnival PLC
#  23                            Centrica PLC
#  24                       Compass Group PLC
#  25                                 CRH PLC
#  26                 Croda International PLC
#  27                              Diageo PLC
#  28     Eurasian Natural Resources Corp Ltd
#  29                               Evraz PLC
#                        ...
#  71        Royal Bank of Scotland Group PLC
#  72                   Royal Dutch Shell PLC
#  73                 RSA Insurance Group PLC
#  74                           SABMiller PLC
#  75                      Sage Group PLC/The
#  76                           Schroders PLC
#  77                         Serco Group PLC
#  78                        Severn Trent PLC
#  79                               Shire PLC
#  80                                 Sky PLC
#  81                      Smith & Nephew PLC
#  82                        Smiths Group PLC
#  83                                 SSE PLC
#  84                  Standard Chartered PLC
#  85                       Standard Life PLC
#  86                         Tate & Lyle PLC
#  87                               Tesco PLC
#  88                          TUI Travel Ltd
#  89                          Tullow Oil PLC
#  90                            Unilever PLC
#  91              United Utilities Group PLC
#  92                   Vedanta Resources PLC
#  93                      Vodafone Group PLC
#  94                      Weir Group PLC/The
#  95                           Whitbread PLC
#  96            Wm Morrison Supermarkets PLC
#  97                            Wolseley PLC
#  98                                 WPP PLC
#  99                             Xstrata Ltd
#  101                              UKX Index
#  Name: 01/01/2013, Length: 101, dtype: object,
#  '12': 0        Aberdeen Asset Management PLC
#  1                    Admiral Group PLC
#  2                          Aggreko PLC
#  3              Amec Foster Wheeler PLC
#  4                   Anglo American PLC
#  5                      Antofagasta PLC
#  6                     ARM Holdings PLC
#  7                    Ashtead Group PLC
#  8         Associated British Foods PLC
#  9                      AstraZeneca PLC
#  10                           Aviva PLC
#  11     Babcock International Group PLC
#  12                     BAE Systems PLC
#  13                        Barclays PLC
#  14                        BG Group Ltd
#  15                    BHP Billiton PLC
#  16                              BP PLC
#  17        British American Tobacco PLC
#  18             British Land Co PLC/The
#  19                        BT Group PLC
#  20                           Bunzl PLC
#  21                  Burberry Group PLC
#  22                          Capita PLC
#  23                        Carnival PLC
#  24                        Centrica PLC
#  25                    Coca-Cola HBC AG
#  26                   Compass Group PLC
#  27                             CRH PLC
#  28                          Diageo PLC
#  29                         easyJet PLC
#                      ...
#  71               Royal Dutch Shell PLC
#  72                      Royal Mail PLC
#  73             RSA Insurance Group PLC
#  74                       SABMiller PLC
#  75                  Sage Group PLC/The
#  76                       Schroders PLC
#  77                    Severn Trent PLC
#  78                           Shire PLC
#  79                             Sky PLC
#  80                  Smith & Nephew PLC
#  81                    Smiths Group PLC
#  82     Sports Direct International PLC
#  83                             SSE PLC
#  84              Standard Chartered PLC
#  85                   Standard Life PLC
#  86                     Tate & Lyle PLC
#  87                           Tesco PLC
#  88                  Travis Perkins PLC
#  89                      TUI Travel Ltd
#  90                      Tullow Oil PLC
#  91                        Unilever PLC
#  92          United Utilities Group PLC
#  93                  Vodafone Group PLC
#  94                  Weir Group PLC/The
#  95                       Whitbread PLC
#  96                    William Hill PLC
#  97        Wm Morrison Supermarkets PLC
#  98                        Wolseley PLC
#  99                             WPP PLC
#  101                          UKX Index
#  Name: 01/01/2014, Length: 101, dtype: object,
#  '13': 0                         3i Group PLC
#  1        Aberdeen Asset Management PLC
#  2                    Admiral Group PLC
#  3                          Aggreko PLC
#  4                   Anglo American PLC
#  5                      Antofagasta PLC
#  6                     ARM Holdings PLC
#  7                    Ashtead Group PLC
#  8         Associated British Foods PLC
#  9                      AstraZeneca PLC
#  10                           Aviva PLC
#  11     Babcock International Group PLC
#  12                     BAE Systems PLC
#  13                        Barclays PLC
#  14            Barratt Developments PLC
#  15                        BG Group Ltd
#  16                    BHP Billiton PLC
#  17                              BP PLC
#  18        British American Tobacco PLC
#  19             British Land Co PLC/The
#  20                        BT Group PLC
#  21                           Bunzl PLC
#  22                  Burberry Group PLC
#  23                          Capita PLC
#  24                        Carnival PLC
#  25                        Centrica PLC
#  26                    Coca-Cola HBC AG
#  27                   Compass Group PLC
#  28                             CRH PLC
#  29                          Diageo PLC
#                      ...
#  71               Royal Dutch Shell PLC
#  72                      Royal Mail PLC
#  73             RSA Insurance Group PLC
#  74                       SABMiller PLC
#  75                  Sage Group PLC/The
#  76                       Schroders PLC
#  77                    Severn Trent PLC
#  78                           Shire PLC
#  79                             Sky PLC
#  80                  Smith & Nephew PLC
#  81                    Smiths Group PLC
#  82     Sports Direct International PLC
#  83                             SSE PLC
#  84                St James's Place PLC
#  85              Standard Chartered PLC
#  86                   Standard Life PLC
#  87                   Taylor Wimpey PLC
#  88                           Tesco PLC
#  89                  Travis Perkins PLC
#  90                              TUI AG
#  91                      Tullow Oil PLC
#  92                        Unilever PLC
#  93          United Utilities Group PLC
#  94                  Vodafone Group PLC
#  95                  Weir Group PLC/The
#  96                       Whitbread PLC
#  97        Wm Morrison Supermarkets PLC
#  98                        Wolseley PLC
#  99                             WPP PLC
#  101                          UKX Index
#  Name: 01/01/2015, Length: 101, dtype: object,
#  '14': 0                          3i Group PLC
#  1         Aberdeen Asset Management PLC
#  2                     Admiral Group PLC
#  3                    Anglo American PLC
#  4                       Antofagasta PLC
#  5                      ARM Holdings PLC
#  6                     Ashtead Group PLC
#  7          Associated British Foods PLC
#  8                       AstraZeneca PLC
#  9                             Aviva PLC
#  10      Babcock International Group PLC
#  11                      BAE Systems PLC
#  12                         Barclays PLC
#  13             Barratt Developments PLC
#  14          Berkeley Group Holdings PLC
#  15                         BG Group Ltd
#  16                     BHP Billiton PLC
#  17                               BP PLC
#  18         British American Tobacco PLC
#  19              British Land Co PLC/The
#  20                         BT Group PLC
#  21                            Bunzl PLC
#  22                   Burberry Group PLC
#  23                           Capita PLC
#  24                         Carnival PLC
#  25                         Centrica PLC
#  26                     Coca-Cola HBC AG
#  27                    Compass Group PLC
#  28                              CRH PLC
#  29                              DCC PLC
#                       ...
#  71             Rolls-Royce Holdings PLC
#  72     Royal Bank of Scotland Group PLC
#  73                Royal Dutch Shell PLC
#  74                       Royal Mail PLC
#  75              RSA Insurance Group PLC
#  76                        SABMiller PLC
#  77                   Sage Group PLC/The
#  78                        Schroders PLC
#  79                     Severn Trent PLC
#  80                            Shire PLC
#  81                              Sky PLC
#  82                   Smith & Nephew PLC
#  83                     Smiths Group PLC
#  84      Sports Direct International PLC
#  85                              SSE PLC
#  86                 St James's Place PLC
#  87               Standard Chartered PLC
#  88                    Standard Life PLC
#  89                    Taylor Wimpey PLC
#  90                            Tesco PLC
#  91                   Travis Perkins PLC
#  92                               TUI AG
#  93                         Unilever PLC
#  94           United Utilities Group PLC
#  95                   Vodafone Group PLC
#  96                        Whitbread PLC
#  97                         Wolseley PLC
#  98                   Worldpay Group PLC
#  99                              WPP PLC
#  101                           UKX Index
#  Name: 01/01/2016, Length: 101, dtype: object,
#  '2': 0                              3i Group PLC
#  1                  Alliance & Leicester Ltd
#  2               Alliance Boots Holdings Ltd
#  3                      Alliance UniChem PLC
#  4                         Allied Domecq Ltd
#  5                        Anglo American PLC
#  6                       Ascential Group Ltd
#  7              Associated British Foods PLC
#  8                           AstraZeneca PLC
#  9                                 Aviva PLC
#  10                          BAE Systems PLC
#  11                             Barclays PLC
#  12                             BG Group Ltd
#  13                         BHP Billiton PLC
#  14                        BOC Group Ltd/The
#  15                                   BP PLC
#  16                   Bradford & Bingley PLC
#  17             British American Tobacco PLC
#  18                  British Land Co PLC/The
#  19                             BT Group PLC
#  20                                Bunzl PLC
#  21      Cable & Wireless Communications Ltd
#  22                              Cadbury Ltd
#  23                             Carnival PLC
#  24                             Centrica PLC
#  25                        Compass Group PLC
#  26           Daily Mail & General Trust PLC
#  27                               Diageo PLC
#  28                  Dixons Retail Group Ltd
#  29                                 Exel Ltd
#                         ...
#  70                 Rolls-Royce Holdings PLC
#  71         Royal Bank of Scotland Group PLC
#  72                  RSA Insurance Group PLC
#  73                            SABMiller PLC
#  74                              Safeway Ltd
#  75                       Sage Group PLC/The
#  76                         Santander UK PLC
#  77                            Schroders PLC
#  78                 Scottish & Newcastle Ltd
#  79                       Scottish Power Ltd
#  80                         Severn Trent PLC
#  81     Shell Transport & Trading Co Ltd/The
#  82                                Shire PLC
#  83                                  Sky PLC
#  84                       Smith & Nephew PLC
#  85                         Smiths Group PLC
#  86                                  SSE PLC
#  87                   Standard Chartered PLC
#  88                    Telefonica Europe PLC
#  89                                Tesco PLC
#  90                   Thomson Reuters UK Ltd
#  91                             Unilever PLC
#  92               United Utilities Group PLC
#  93                       Vodafone Group PLC
#  94                            Whitbread PLC
#  95             Wm Morrison Supermarkets PLC
#  96                             Wolseley PLC
#  97                                  WPP PLC
#  98                              Xstrata Ltd
#  101                               UKX Index
#  Name: 01/01/2004, Length: 100, dtype: object,
#  '3': 0                              3i Group PLC
#  1                  Alliance & Leicester Ltd
#  2               Alliance Boots Holdings Ltd
#  3                      Alliance UniChem PLC
#  4                         Allied Domecq Ltd
#  5                        Anglo American PLC
#  6                           Antofagasta PLC
#  7                       Ascential Group Ltd
#  8              Associated British Foods PLC
#  9                           AstraZeneca PLC
#  10                                Aviva PLC
#  11                          BAE Systems PLC
#  12                             Barclays PLC
#  13                             BG Group Ltd
#  14                         BHP Billiton PLC
#  15                        BOC Group Ltd/The
#  16                                   BP PLC
#  17             British American Tobacco PLC
#  18                  British Land Co PLC/The
#  19                             BT Group PLC
#  20                                Bunzl PLC
#  21      Cable & Wireless Communications Ltd
#  22                              Cadbury Ltd
#  23                         Cairn Energy PLC
#  24                               Capita PLC
#  25                             Carnival PLC
#  26                             Centrica PLC
#  27                        Compass Group PLC
#  28                          Corus Group Ltd
#  29           Daily Mail & General Trust PLC
#                         ...
#  71                 Rolls-Royce Holdings PLC
#  72         Royal Bank of Scotland Group PLC
#  73                  RSA Insurance Group PLC
#  74                            SABMiller PLC
#  75                       Sage Group PLC/The
#  76                            Schroders PLC
#  77                 Scottish & Newcastle Ltd
#  78                       Scottish Power Ltd
#  79                         Severn Trent PLC
#  80     Shell Transport & Trading Co Ltd/The
#  81                                Shire PLC
#  82                                  Sky PLC
#  83                       Smith & Nephew PLC
#  84                         Smiths Group PLC
#  85                                  SSE PLC
#  86                   Standard Chartered PLC
#  87                          Tate & Lyle PLC
#  88                    Telefonica Europe PLC
#  89                                Tesco PLC
#  90                   Thomson Reuters UK Ltd
#  91                             Unilever PLC
#  92               United Utilities Group PLC
#  93                       Vodafone Group PLC
#  94                            Whitbread PLC
#  95                         William Hill PLC
#  96             Wm Morrison Supermarkets PLC
#  97                             Wolseley PLC
#  98                                  WPP PLC
#  99                              Xstrata Ltd
#  101                               UKX Index
#  Name: 01/01/2005, Length: 101, dtype: object,
#  '4': 0                              3i Group PLC
#  1                  Alliance & Leicester Ltd
#  2               Alliance Boots Holdings Ltd
#  3                      Alliance UniChem PLC
#  4                        Anglo American PLC
#  5                           Antofagasta PLC
#  6              Associated British Foods PLC
#  7                           AstraZeneca PLC
#  8                                 Aviva PLC
#  9                           BAE Systems PLC
#  10                             Barclays PLC
#  11                             BG Group Ltd
#  12                         BHP Billiton PLC
#  13                       BIP Industries Ltd
#  14                        BOC Group Ltd/The
#  15                                   BP PLC
#  16             British American Tobacco PLC
#  17                  British Land Co PLC/The
#  18                             BT Group PLC
#  19     Bwin Party Digital Entertainment PLC
#  20      Cable & Wireless Communications Ltd
#  21                              Cadbury Ltd
#  22                         Cairn Energy PLC
#  23                               Capita PLC
#  24                             Carnival PLC
#  25                             Centrica PLC
#  26                        Compass Group PLC
#  27           Daily Mail & General Trust PLC
#  28                               Diageo PLC
#  29                  Dixons Retail Group Ltd
#                         ...
#  70                                Rexam Ltd
#  71                            Rio Tinto PLC
#  72                 Rolls-Royce Holdings PLC
#  73         Royal Bank of Scotland Group PLC
#  74                    Royal Dutch Shell PLC
#  75                  RSA Insurance Group PLC
#  76                            SABMiller PLC
#  77                       Sage Group PLC/The
#  78                            Schroders PLC
#  79                 Scottish & Newcastle Ltd
#  80                       Scottish Power Ltd
#  81                         Severn Trent PLC
#  82                                Shire PLC
#  83                                  Sky PLC
#  84                       Smith & Nephew PLC
#  85                         Smiths Group PLC
#  86                                  SSE PLC
#  87                   Standard Chartered PLC
#  88                          Tate & Lyle PLC
#  89                    Telefonica Europe PLC
#  90                                Tesco PLC
#  91                   Thomson Reuters UK Ltd
#  92                             Unilever PLC
#  93               United Utilities Group PLC
#  94                       Vodafone Group PLC
#  95             Wm Morrison Supermarkets PLC
#  96                             Wolseley PLC
#  97                                  WPP PLC
#  98                              Xstrata Ltd
#  101                               UKX Index
#  Name: 01/01/2006, Length: 100, dtype: object,
#  '5': 0                             3i Group PLC
#  1                 Alliance & Leicester Ltd
#  2              Alliance Boots Holdings Ltd
#  3                       Anglo American PLC
#  4                          Antofagasta PLC
#  5             Associated British Foods PLC
#  6                          AstraZeneca PLC
#  7                                Aviva PLC
#  8                          BAE Systems PLC
#  9                             Barclays PLC
#  10                            BG Group Ltd
#  11                        BHP Billiton PLC
#  12                                  BP PLC
#  13                  Bradford & Bingley PLC
#  14            British American Tobacco PLC
#  15                 British Land Co PLC/The
#  16                            BT Group PLC
#  17     Cable & Wireless Communications Ltd
#  18                             Cadbury Ltd
#  19                        Cairn Energy PLC
#  20                              Capita PLC
#  21                            Carnival PLC
#  22                            Centrica PLC
#  23                       Compass Group PLC
#  24                         Corus Group Ltd
#  25                              Diageo PLC
#  26                 Dixons Retail Group Ltd
#  27                          Drax Group PLC
#  28                            EI Group PLC
#  29                            Experian PLC
#                        ...
#  71                Rolls-Royce Holdings PLC
#  72        Royal Bank of Scotland Group PLC
#  73                   Royal Dutch Shell PLC
#  74                 RSA Insurance Group PLC
#  75                           SABMiller PLC
#  76                      Sage Group PLC/The
#  77                Scottish & Newcastle Ltd
#  78                      Scottish Power Ltd
#  79                               Segro PLC
#  80                        Severn Trent PLC
#  81                               Shire PLC
#  82                                 Sky PLC
#  83                      Smith & Nephew PLC
#  84                        Smiths Group PLC
#  85                                 SSE PLC
#  86                  Standard Chartered PLC
#  87                       Standard Life PLC
#  88                         Tate & Lyle PLC
#  89                               Tesco PLC
#  90                  Thomson Reuters UK Ltd
#  91                            Unilever PLC
#  92              United Utilities Group PLC
#  93                   Vedanta Resources PLC
#  94                      Vodafone Group PLC
#  95                           Whitbread PLC
#  96            Wm Morrison Supermarkets PLC
#  97                            Wolseley PLC
#  98                                 WPP PLC
#  99                             Xstrata Ltd
#  101                              UKX Index
#  Name: 01/01/2007, Length: 101, dtype: object,
#  '6': 0                                 3i Group PLC
#  1                            Admiral Group PLC
#  2                     Alliance & Leicester Ltd
#  3                      Amec Foster Wheeler PLC
#  4                           Anglo American PLC
#  5                              Antofagasta PLC
#  6                 Associated British Foods PLC
#  7                              AstraZeneca PLC
#  8                                    Aviva PLC
#  9                              BAE Systems PLC
#  10                                Barclays PLC
#  11                                BG Group Ltd
#  12                            BHP Billiton PLC
#  13                                      BP PLC
#  14                British American Tobacco PLC
#  15                     British Land Co PLC/The
#  16                                BT Group PLC
#  17         Cable & Wireless Communications Ltd
#  18                                 Cadbury Ltd
#  19                            Cairn Energy PLC
#  20                                  Capita PLC
#  21                                Carnival PLC
#  22            Carphone Warehouse Group PLC\Old
#  23                                Centrica PLC
#  24                           Compass Group PLC
#  25                                  Diageo PLC
#  26     EDF Energy Nuclear Generation Group Ltd
#  27                                EI Group PLC
#  28                                Experian PLC
#  29                              Firstgroup PLC
#                          ...
#  71                       Royal Dutch Shell PLC
#  72                     RSA Insurance Group PLC
#  73                               SABMiller PLC
#  74                          Sage Group PLC/The
#  75                               Schroders PLC
#  76                    Scottish & Newcastle Ltd
#  77                            Severn Trent PLC
#  78                                   Shire PLC
#  79                                     Sky PLC
#  80                          Smith & Nephew PLC
#  81                            Smiths Group PLC
#  82                                     SSE PLC
#  83                      Standard Chartered PLC
#  84                           Standard Life PLC
#  85                           Taylor Wimpey PLC
#  86                                   Tesco PLC
#  87                       Thomas Cook Group PLC
#  88                      Thomson Reuters UK Ltd
#  89                              TUI Travel Ltd
#  90                              Tullow Oil PLC
#  91                                Unilever PLC
#  92                  United Utilities Group PLC
#  93                       Vedanta Resources PLC
#  94                          Vodafone Group PLC
#  95                               Whitbread PLC
#  96                Wm Morrison Supermarkets PLC
#  97                                Wolseley PLC
#  98                                     WPP PLC
#  99                                 Xstrata Ltd
#  101                                  UKX Index
#  Name: 01/01/2008, Length: 101, dtype: object,
#  '7': 0                                 3i Group PLC
#  1                            Admiral Group PLC
#  2                           Alliance Trust PLC
#  3                      Amec Foster Wheeler PLC
#  4                           Anglo American PLC
#  5                              Antofagasta PLC
#  6                 Associated British Foods PLC
#  7                              AstraZeneca PLC
#  8                            Autonomy Corp Ltd
#  9                                    Aviva PLC
#  10                             BAE Systems PLC
#  11                                Barclays PLC
#  12                                BG Group Ltd
#  13                            BHP Billiton PLC
#  14                                      BP PLC
#  15                British American Tobacco PLC
#  16                     British Land Co PLC/The
#  17                                BT Group PLC
#  18                                   Bunzl PLC
#  19         Cable & Wireless Communications Ltd
#  20                                 Cadbury Ltd
#  21                            Cairn Energy PLC
#  22                                  Capita PLC
#  23                                Carnival PLC
#  24                                Centrica PLC
#  25                                  Cobham PLC
#  26                           Compass Group PLC
#  27                                  Diageo PLC
#  28                              Drax Group PLC
#  29     EDF Energy Nuclear Generation Group Ltd
#                          ...
#  71                       Royal Dutch Shell PLC
#  72                     RSA Insurance Group PLC
#  73                               SABMiller PLC
#  74                          Sage Group PLC/The
#  75                               Schroders PLC
#  76                             Serco Group PLC
#  77                            Severn Trent PLC
#  78                                   Shire PLC
#  79                                     Sky PLC
#  80                          Smith & Nephew PLC
#  81                            Smiths Group PLC
#  82                                     SSE PLC
#  83                      Standard Chartered PLC
#  84                           Standard Life PLC
#  85                             Tate & Lyle PLC
#  86                                   Tesco PLC
#  87                       Thomas Cook Group PLC
#  88                      Thomson Reuters UK Ltd
#  89                              TUI Travel Ltd
#  90                              Tullow Oil PLC
#  91                                Unilever PLC
#  92                  United Utilities Group PLC
#  93                       Vedanta Resources PLC
#  94                          Vodafone Group PLC
#  95                               Whitbread PLC
#  96                Wm Morrison Supermarkets PLC
#  97                                Wolseley PLC
#  98                                     WPP PLC
#  99                                 Xstrata Ltd
#  101                                  UKX Index
#  Name: 01/01/2009, Length: 101, dtype: object,
#  '8': 0                             3i Group PLC
#  1                        Admiral Group PLC
#  2                              Aggreko PLC
#  3                       Alliance Trust PLC
#  4                  Amec Foster Wheeler PLC
#  5                       Anglo American PLC
#  6                          Antofagasta PLC
#  7             Associated British Foods PLC
#  8                          AstraZeneca PLC
#  9                        Autonomy Corp Ltd
#  10                               Aviva PLC
#  11                         BAE Systems PLC
#  12                            Barclays PLC
#  13                            BG Group Ltd
#  14                        BHP Billiton PLC
#  15                                  BP PLC
#  16            British American Tobacco PLC
#  17                 British Land Co PLC/The
#  18                            BT Group PLC
#  19                               Bunzl PLC
#  20                      Burberry Group PLC
#  21     Cable & Wireless Communications Ltd
#  22                             Cadbury Ltd
#  23                        Cairn Energy PLC
#  24                              Capita PLC
#  25                            Carnival PLC
#  26                            Centrica PLC
#  27                              Cobham PLC
#  28                       Compass Group PLC
#  29                              Diageo PLC
#                        ...
#  71        Royal Bank of Scotland Group PLC
#  72                   Royal Dutch Shell PLC
#  73                 RSA Insurance Group PLC
#  74                           SABMiller PLC
#  75                      Sage Group PLC/The
#  76                           Schroders PLC
#  77                               Segro PLC
#  78                         Serco Group PLC
#  79                        Severn Trent PLC
#  80                               Shire PLC
#  81                                 Sky PLC
#  82                      Smith & Nephew PLC
#  83                        Smiths Group PLC
#  84                                 SSE PLC
#  85                  Standard Chartered PLC
#  86                       Standard Life PLC
#  87                               Tesco PLC
#  88                   Thomas Cook Group PLC
#  89                          TUI Travel Ltd
#  90                          Tullow Oil PLC
#  91                            Unilever PLC
#  92              United Utilities Group PLC
#  93                   Vedanta Resources PLC
#  94                      Vodafone Group PLC
#  95                           Whitbread PLC
#  96            Wm Morrison Supermarkets PLC
#  97                            Wolseley PLC
#  98                                 WPP PLC
#  99                             Xstrata Ltd
#  101                              UKX Index
#  Name: 01/01/2010, Length: 101, dtype: object,
#  '9': 0                          3i Group PLC
#  1                     Acacia Mining PLC
#  2                     Admiral Group PLC
#  3                           Aggreko PLC
#  4                    Alliance Trust PLC
#  5               Amec Foster Wheeler PLC
#  6                    Anglo American PLC
#  7                       Antofagasta PLC
#  8                      ARM Holdings PLC
#  9          Associated British Foods PLC
#  10                      AstraZeneca PLC
#  11                    Autonomy Corp Ltd
#  12                            Aviva PLC
#  13                      BAE Systems PLC
#  14                         Barclays PLC
#  15                         BG Group Ltd
#  16                     BHP Billiton PLC
#  17                               BP PLC
#  18         British American Tobacco PLC
#  19              British Land Co PLC/The
#  20                         BT Group PLC
#  21                            Bunzl PLC
#  22                   Burberry Group PLC
#  23                     Cairn Energy PLC
#  24                           Capita PLC
#  25                         Carnival PLC
#  26                         Centrica PLC
#  27                    Compass Group PLC
#  28                           Diageo PLC
#  29                     Essar Energy Ltd
#                       ...
#  71             Rolls-Royce Holdings PLC
#  72     Royal Bank of Scotland Group PLC
#  73                Royal Dutch Shell PLC
#  74              RSA Insurance Group PLC
#  75                        SABMiller PLC
#  76                   Sage Group PLC/The
#  77                        Schroders PLC
#  78                      Serco Group PLC
#  79                     Severn Trent PLC
#  80                            Shire PLC
#  81                              Sky PLC
#  82                   Smith & Nephew PLC
#  83                     Smiths Group PLC
#  84                              SSE PLC
#  85               Standard Chartered PLC
#  86                    Standard Life PLC
#  87                            Tesco PLC
#  88                       TUI Travel Ltd
#  89                       Tullow Oil PLC
#  90                         Unilever PLC
#  91           United Utilities Group PLC
#  92                Vedanta Resources PLC
#  93                   Vodafone Group PLC
#  94                   Weir Group PLC/The
#  95                        Whitbread PLC
#  96         Wm Morrison Supermarkets PLC
#  97                         Wolseley PLC
#  98                              WPP PLC
#  99                          Xstrata Ltd
#  101                           UKX Index
#  Name: 01/01/2011, Length: 101, dtype: object}

# %%
len(pick.investmentuniverse.columns)
# Out:
# 15

# %%
Portfolios["2"]
# Out:
#             3i Group PLC  Alliance & Leicester Ltd  \
# Date
# 2002-01-02        738.96                    811.00
# 2002-01-03        753.25                    843.00
# 2002-01-04        768.40                    867.50
# 2002-01-07        766.24                    863.00
# 2002-01-08        760.18                    853.00
# 2002-01-09        746.32                    861.00
# 2002-01-10        721.65                    867.00
# 2002-01-11        725.11                    870.50
# 2002-01-14        716.45                    857.00
# 2002-01-15        734.20                    861.00
# 2002-01-16        713.42                    858.00
# 2002-01-17        711.69                    875.00
# 2002-01-18        692.64                    858.00
# 2002-01-21        695.24                    864.00
# 2002-01-22        699.14                    871.50
# 2002-01-23        669.27                    867.50
# 2002-01-24        666.67                    857.50
# 2002-01-25        675.33                    851.00
# 2002-01-28        664.07                    863.50
# 2002-01-29        655.85                    848.00
# 2002-01-30        652.82                    836.00
# 2002-01-31        663.21                    853.00
# 2002-02-01        661.47                    857.00
# 2002-02-04        653.68                    851.50
# 2002-02-05        635.93                    855.00
# 2002-02-06        632.47                    844.50
# 2002-02-07        643.29                    838.00
# 2002-02-08        645.02                    835.00
# 2002-02-11        639.40                    849.50
# 2002-02-12        628.14                    846.00
# ...                  ...                       ...
# 2002-11-20        467.97                    882.00
# 2002-11-21        483.12                    877.50
# 2002-11-22        492.64                    873.50
# 2002-11-25        479.65                    845.00
# 2002-11-26        476.19                    830.00
# 2002-11-27        481.39                    824.00
# 2002-11-28        499.14                    818.00
# 2002-11-29        515.15                    820.00
# 2002-12-02        515.15                    808.50
# 2002-12-03        501.30                    789.50
# 2002-12-04        483.12                    790.00
# 2002-12-05        480.52                    772.00
# 2002-12-06        480.95                    763.00
# 2002-12-09        459.31                    733.50
# 2002-12-10        456.28                    766.50
# 2002-12-11        457.14                    778.50
# 2002-12-12        462.34                    755.00
# 2002-12-13        458.01                    747.50
# 2002-12-16        466.67                    763.50
# 2002-12-17        463.20                    752.50
# 2002-12-18        463.20                    732.00
# 2002-12-19        459.31                    733.00
# 2002-12-20        464.50                    738.50
# 2002-12-23        466.24                    748.00
# 2002-12-24        461.47                    754.50
# 2002-12-25           nan                       nan
# 2002-12-26           nan                       nan
# 2002-12-27        455.85                    728.00
# 2002-12-30        469.27                    735.00
# 2002-12-31        480.52                    746.00
#
#             Alliance Boots Holdings Ltd  Allied Domecq Ltd  \
# Date
# 2002-01-02                       881.90             401.00
# 2002-01-03                       890.82             397.00
# 2002-01-04                       892.31             397.25
# 2002-01-07                       890.82             393.00
# 2002-01-08                       884.87             389.50
# 2002-01-09                       858.10             390.00
# 2002-01-10                       890.82             387.00
# 2002-01-11                       893.79             390.75
# 2002-01-14                       885.62             392.50
# 2002-01-15                       892.31             400.00
# 2002-01-16                       893.79             393.00
# 2002-01-17                       916.10             395.00
# 2002-01-18                       934.69             388.00
# 2002-01-21                       932.46             395.00
# 2002-01-22                       939.15             389.00
# 2002-01-23                       953.28             386.00
# 2002-01-24                       946.59             392.75
# 2002-01-25                       942.87             392.25
# 2002-01-28                       952.54             391.00
# 2002-01-29                       948.82             391.00
# 2002-01-30                       953.28             386.00
# 2002-01-31                       969.64             395.00
# 2002-02-01                       956.26             403.00
# 2002-02-04                       951.79             404.00
# 2002-02-05                       959.23             400.75
# 2002-02-06                       964.44             407.25
# 2002-02-07                       963.69             400.25
# 2002-02-08                       950.31             402.00
# 2002-02-11                       948.82             407.00
# 2002-02-12                       947.33             408.00
# ...                                 ...                ...
# 2002-11-20                       846.21             390.00
# 2002-11-21                       859.59             390.00
# 2002-11-22                       861.08             377.00
# 2002-11-25                       858.10             384.00
# 2002-11-26                       848.44             388.25
# 2002-11-27                       859.59             396.50
# 2002-11-28                       867.03             393.75
# 2002-11-29                       848.44             380.75
# 2002-12-02                       855.13             370.00
# 2002-12-03                       853.64             372.50
# 2002-12-04                       846.21             375.25
# 2002-12-05                       844.72             382.50
# 2002-12-06                       842.49             377.50
# 2002-12-09                       829.85             382.25
# 2002-12-10                       825.38             382.00
# 2002-12-11                       834.31             384.50
# 2002-12-12                       844.72             379.00
# 2002-12-13                       817.95             380.50
# 2002-12-16                       846.95             388.50
# 2002-12-17                       844.72             386.50
# 2002-12-18                       827.62             383.00
# 2002-12-19                       843.23             386.50
# 2002-12-20                       838.77             387.00
# 2002-12-23                       862.56             395.00
# 2002-12-24                       865.54             394.75
# 2002-12-25                          nan                nan
# 2002-12-26                          nan                nan
# 2002-12-27                       850.67             388.50
# 2002-12-30                       867.77             401.75
# 2002-12-31                       871.49             397.00
#
#             Anglo American PLC  ARM Holdings PLC  \
# Date
# 2002-01-02            1,115.23            349.00
# 2002-01-03            1,136.86            382.50
# 2002-01-04            1,165.69            385.75
# 2002-01-07            1,194.53            377.00
# 2002-01-08            1,196.59            365.00
# 2002-01-09            1,234.69            360.25
# 2002-01-10            1,204.82            348.50
# 2002-01-11            1,215.12            347.50
# 2002-01-14            1,153.34            336.00
# 2002-01-15            1,165.69            343.50
# 2002-01-16            1,148.19            325.50
# 2002-01-17            1,171.87            325.00
# 2002-01-18            1,179.08            311.00
# 2002-01-21            1,175.99            302.50
# 2002-01-22            1,194.53            303.00
# 2002-01-23            1,199.67            303.00
# 2002-01-24            1,215.12            333.00
# 2002-01-25            1,203.79            335.00
# 2002-01-28            1,199.67            308.00
# 2002-01-29            1,181.14            311.25
# 2002-01-30            1,160.54            313.75
# 2002-01-31            1,199.67            328.00
# 2002-02-01            1,232.63            313.00
# 2002-02-04            1,220.27            308.00
# 2002-02-05            1,229.54            306.00
# 2002-02-06            1,267.64            290.75
# 2002-02-07            1,240.87            297.50
# 2002-02-08            1,256.31            294.00
# 2002-02-11            1,259.40            300.00
# 2002-02-12            1,271.76            304.75
# ...                        ...               ...
# 2002-11-20              887.66             58.50
# 2002-11-21              913.40             64.75
# 2002-11-22              909.28             64.00
# 2002-11-25              909.28             65.00
# 2002-11-26              885.60             66.00
# 2002-11-27              892.80             67.00
# 2002-11-28              900.53             69.00
# 2002-11-29              931.94             67.50
# 2002-12-02              945.32             72.50
# 2002-12-03              920.61             69.00
# 2002-12-04              931.94             65.50
# 2002-12-05              925.24             67.00
# 2002-12-06              906.19             67.25
# 2002-12-09              888.69             62.75
# 2002-12-10              867.58             61.50
# 2002-12-11              881.48             58.75
# 2002-12-12              882.51             55.50
# 2002-12-13              887.66             53.50
# 2002-12-16              914.95             57.25
# 2002-12-17              926.79             56.00
# 2002-12-18              916.49             51.75
# 2002-12-19              923.70             51.25
# 2002-12-20              931.94             51.75
# 2002-12-23              943.26             53.00
# 2002-12-24              952.02             52.25
# 2002-12-25                 nan               nan
# 2002-12-26                 nan               nan
# 2002-12-27              930.39             49.75
# 2002-12-30              946.35             49.50
# 2002-12-31              949.96             48.00
#
#             Associated British Foods PLC  AstraZeneca PLC  Aviva PLC  \
# Date
# 2002-01-02                        487.50         3,120.00     846.00
# 2002-01-03                        495.50         3,165.00     852.00
# 2002-01-04                        497.00         3,098.00     844.00
# 2002-01-07                        494.50         3,077.00     838.00
# 2002-01-08                        495.00         3,051.00     829.50
# 2002-01-09                        490.00         3,095.00     815.00
# 2002-01-10                        486.00         3,075.00     824.00
# 2002-01-11                        480.50         3,115.00     819.00
# 2002-01-14                        484.50         3,082.00     800.50
# 2002-01-15                        490.50         3,099.00     812.00
# 2002-01-16                        477.50         3,101.00     821.50
# 2002-01-17                        475.50         3,088.00     833.00
# 2002-01-18                        470.00         3,125.00     830.50
# 2002-01-21                        481.00         3,136.00     836.00
# 2002-01-22                        480.00         3,166.00     873.00
# 2002-01-23                        479.00         3,214.00     867.00
# 2002-01-24                        479.00         3,200.00     869.50
# 2002-01-25                        476.00         3,141.00     857.00
# 2002-01-28                        480.00         3,124.00     854.50
# 2002-01-29                        475.00         3,086.00     848.50
# 2002-01-30                        476.50         3,090.00     829.00
# 2002-01-31                        476.00         3,250.00     826.00
# 2002-02-01                        483.50         3,331.00     819.50
# 2002-02-04                        488.00         3,345.00     809.00
# 2002-02-05                        486.50         3,378.00     803.00
# 2002-02-06                        482.00         3,378.00     792.00
# 2002-02-07                        482.00         3,385.00     808.00
# 2002-02-08                        481.00         3,380.00     804.00
# 2002-02-11                        486.00         3,397.00     814.00
# 2002-02-12                        483.00         3,428.00     820.00
# ...                                  ...              ...        ...
# 2002-11-20                        598.00         2,480.00     512.00
# 2002-11-21                        590.50         2,523.00     543.00
# 2002-11-22                        587.00         2,477.00     554.00
# 2002-11-25                        573.50         2,426.00     540.00
# 2002-11-26                        569.50         2,426.00     523.00
# 2002-11-27                        579.00         2,470.00     531.00
# 2002-11-28                        571.00         2,452.00     549.00
# 2002-11-29                        554.00         2,446.00     548.50
# 2002-12-02                        551.00         2,430.00     554.50
# 2002-12-03                        547.00         2,406.00     531.00
# 2002-12-04                        566.00         2,407.00     521.50
# 2002-12-05                        569.00         2,356.00     510.00
# 2002-12-06                        564.00         2,308.00     504.50
# 2002-12-09                        568.00         2,290.00     483.00
# 2002-12-10                        565.00         2,238.00     467.50
# 2002-12-11                        565.00         2,315.00     479.00
# 2002-12-12                        567.00         2,321.00     470.50
# 2002-12-13                        565.00         2,306.00     459.00
# 2002-12-16                        565.00         2,313.00     484.00
# 2002-12-17                        557.50         2,235.00     478.00
# 2002-12-18                        566.00         2,200.00     459.00
# 2002-12-19                        564.00         2,215.00     438.50
# 2002-12-20                        563.00         2,228.00     453.00
# 2002-12-23                        565.00         2,279.00     458.50
# 2002-12-24                        561.50         2,299.00     456.50
# 2002-12-25                           nan              nan        nan
# 2002-12-26                           nan              nan        nan
# 2002-12-27                        551.50         2,194.00     434.50
# 2002-12-30                        567.00         2,200.00     444.00
# 2002-12-31                        588.00         2,220.00     443.00
#
#             BAE Systems PLC    ...      Telefonica Europe PLC  Tesco PLC  \
# Date                           ...
# 2002-01-02           314.00    ...                      89.00     249.00
# 2002-01-03           315.00    ...                      91.00     251.25
# 2002-01-04           320.00    ...                      90.25     251.00
# 2002-01-07           324.50    ...                      89.50     246.75
# 2002-01-08           321.25    ...                      91.50     243.00
# 2002-01-09           326.00    ...                      87.50     242.50
# 2002-01-10           323.50    ...                      87.00     239.25
# 2002-01-11           321.25    ...                      86.75     236.00
# 2002-01-14           324.50    ...                      85.00     237.00
# 2002-01-15           322.00    ...                      88.00     237.75
# 2002-01-16           325.00    ...                      86.50     233.00
# 2002-01-17           327.50    ...                      86.25     238.00
# 2002-01-18           327.00    ...                      85.50     231.50
# 2002-01-21           329.00    ...                      85.25     231.75
# 2002-01-22           327.50    ...                      82.50     232.00
# 2002-01-23           333.00    ...                      81.00     232.00
# 2002-01-24           342.00    ...                      82.50     234.50
# 2002-01-25           343.50    ...                      81.25     235.25
# 2002-01-28           343.00    ...                      81.00     238.50
# 2002-01-29           337.00    ...                      79.50     235.00
# 2002-01-30           338.50    ...                      76.25     233.75
# 2002-01-31           340.00    ...                      76.75     234.75
# 2002-02-01           343.00    ...                      77.50     241.50
# 2002-02-04           342.75    ...                      74.75     248.75
# 2002-02-05           334.75    ...                      72.50     247.75
# 2002-02-06           340.00    ...                      70.50     246.50
# 2002-02-07           347.25    ...                      74.00     248.50
# 2002-02-08           350.00    ...                      72.25     245.50
# 2002-02-11           344.50    ...                      71.50     253.00
# 2002-02-12           335.00    ...                      71.50     248.00
# ...                     ...    ...                        ...        ...
# 2002-11-20           175.00    ...                      51.75     200.25
# 2002-11-21           172.00    ...                      55.00     201.75
# 2002-11-22           175.00    ...                      54.75     196.00
# 2002-11-25           171.25    ...                      53.50     194.50
# 2002-11-26           172.25    ...                      48.00     194.50
# 2002-11-27           170.00    ...                      52.00     200.50
# 2002-11-28           167.75    ...                      51.25     203.50
# 2002-11-29           169.25    ...                      51.00     203.00
# 2002-12-02           169.50    ...                      52.75     202.50
# 2002-12-03           176.75    ...                      52.50     198.50
# 2002-12-04           179.75    ...                      53.00     199.75
# 2002-12-05           175.50    ...                      51.50     197.25
# 2002-12-06           179.25    ...                      51.75     195.50
# 2002-12-09           178.50    ...                      49.00     193.50
# 2002-12-10           163.50    ...                      47.25     193.50
# 2002-12-11           131.00    ...                      49.25     198.00
# 2002-12-12           104.00    ...                      49.25     196.00
# 2002-12-13           115.25    ...                      47.25     193.25
# 2002-12-16           116.25    ...                      50.75     197.25
# 2002-12-17           117.00    ...                      49.00     190.75
# 2002-12-18           122.25    ...                      44.75     187.50
# 2002-12-19           124.00    ...                      46.25     188.00
# 2002-12-20           127.75    ...                      47.00     189.25
# 2002-12-23           126.00    ...                      47.00     190.50
# 2002-12-24           123.75    ...                      46.50     190.25
# 2002-12-25              nan    ...                        nan        nan
# 2002-12-26              nan    ...                        nan        nan
# 2002-12-27           127.25    ...                      44.50     187.00
# 2002-12-30           122.75    ...                      44.25     193.25
# 2002-12-31           124.00    ...                      44.25     194.00
#
#             Thomson Reuters UK Ltd  Unilever PLC  United Utilities Group PLC  \
# Date
# 2002-01-02                4,331.25      1,262.22                      672.46
# 2002-01-03                4,562.50      1,253.33                      683.65
# 2002-01-04                4,668.75      1,240.00                      683.65
# 2002-01-07                4,587.50      1,228.89                      686.44
# 2002-01-08                4,528.12      1,221.11                      686.44
# 2002-01-09                4,475.00      1,228.89                      674.70
# 2002-01-10                4,375.00      1,213.33                      669.10
# 2002-01-11                4,309.38      1,211.11                      676.37
# 2002-01-14                4,212.50      1,211.11                      673.58
# 2002-01-15                4,237.50      1,224.44                      687.56
# 2002-01-16                4,106.25      1,228.89                      695.95
# 2002-01-17                3,946.88      1,240.00                      692.60
# 2002-01-18                3,853.12      1,247.78                      689.24
# 2002-01-21                3,746.88      1,261.11                      697.63
# 2002-01-22                3,800.00      1,266.67                      674.13
# 2002-01-23                3,593.75      1,257.78                      671.34
# 2002-01-24                3,781.25      1,264.44                      683.65
# 2002-01-25                3,656.25      1,251.11                      674.70
# 2002-01-28                3,706.25      1,246.67                      671.34
# 2002-01-29                3,543.75      1,231.11                      671.34
# 2002-01-30                3,612.50      1,241.11                      669.10
# 2002-01-31                3,762.50      1,265.56                      673.58
# 2002-02-01                3,750.00      1,277.78                      665.74
# 2002-02-04                3,656.25      1,281.11                      670.22
# 2002-02-05                3,609.38      1,276.67                      682.53
# 2002-02-06                3,571.88      1,276.67                      685.88
# 2002-02-07                3,675.00      1,277.78                      690.36
# 2002-02-08                3,737.50      1,262.22                      685.32
# 2002-02-11                3,700.00      1,277.78                      675.81
# 2002-02-12                3,450.00      1,291.11                      679.17
# ...                            ...           ...                         ...
# 2002-11-20                1,253.12      1,316.67                      683.65
# 2002-11-21                1,323.44      1,336.67                      686.44
# 2002-11-22                1,362.50      1,347.78                      674.70
# 2002-11-25                1,343.75      1,304.44                      670.22
# 2002-11-26                1,309.38      1,286.67                      667.42
# 2002-11-27                1,357.81      1,295.56                      685.88
# 2002-11-28                1,453.12      1,293.33                      673.58
# 2002-11-29                1,468.75      1,272.22                      673.58
# 2002-12-02                1,471.88      1,262.22                      675.81
# 2002-12-03                1,367.19      1,255.56                      671.34
# 2002-12-04                1,339.06      1,282.22                      672.46
# 2002-12-05                1,348.44      1,286.67                      681.41
# 2002-12-06                1,331.25      1,286.67                      682.53
# 2002-12-09                1,259.38      1,264.44                      690.92
# 2002-12-10                1,256.25      1,267.78                      680.29
# 2002-12-11                1,312.50      1,295.56                      695.95
# 2002-12-12                1,267.19      1,300.00                      704.90
# 2002-12-13                1,267.19      1,278.89                      710.50
# 2002-12-16                1,248.44      1,317.78                      718.33
# 2002-12-17                1,187.50      1,282.22                      712.74
# 2002-12-18                1,187.50      1,248.89                      695.95
# 2002-12-19                1,195.31      1,275.56                      704.90
# 2002-12-20                1,185.94      1,297.78                      692.60
# 2002-12-23                1,162.50      1,305.56                      704.90
# 2002-12-24                1,156.25      1,308.89                      697.07
# 2002-12-25                     nan           nan                         nan
# 2002-12-26                     nan           nan                         nan
# 2002-12-27                1,104.69      1,275.56                      685.88
# 2002-12-30                1,118.75      1,312.22                      695.95
# 2002-12-31                1,109.38      1,313.33                      698.19
#
#             Vodafone Group PLC  Wm Morrison Supermarkets PLC  Wolseley PLC  \
# Date
# 2002-01-02              252.03                        201.50      2,560.91
# 2002-01-03              261.28                        204.75      2,608.21
# 2002-01-04              262.35                        205.25      2,585.69
# 2002-01-07              258.44                        201.00      2,581.18
# 2002-01-08              253.81                        200.00      2,581.18
# 2002-01-09              243.13                        196.50      2,554.15
# 2002-01-10              234.23                        196.50      2,486.58
# 2002-01-11              238.50                        198.50      2,475.32
# 2002-01-14              229.25                        197.50      2,475.32
# 2002-01-15              234.59                        198.00      2,482.08
# 2002-01-16              231.38                        198.00      2,466.31
# 2002-01-17              235.65                        199.50      2,455.05
# 2002-01-18              235.65                        196.50      2,448.29
# 2002-01-21              232.45                        197.25      2,477.57
# 2002-01-22              229.96                        198.00      2,452.80
# 2002-01-23              226.04                        197.00      2,473.07
# 2002-01-24              234.59                        195.50      2,477.57
# 2002-01-25              231.74                        196.00      2,448.29
# 2002-01-28              228.53                        196.50      2,446.04
# 2002-01-29              219.63                        195.25      2,405.50
# 2002-01-30              213.94                        193.00      2,441.54
# 2002-01-31              216.79                        195.00      2,459.55
# 2002-02-01              219.63                        200.50      2,491.09
# 2002-02-04              212.16                        201.75      2,459.55
# 2002-02-05              203.97                        202.00      2,437.03
# 2002-02-06              194.36                        201.00      2,432.53
# 2002-02-07              205.40                        203.00      2,468.57
# 2002-02-08              205.40                        203.00      2,468.57
# 2002-02-11              203.62                        207.25      2,464.06
# 2002-02-12              194.00                        207.50      2,506.86
# ...                        ...                           ...           ...
# 2002-11-20              170.15                        216.25      2,373.97
# 2002-11-21              179.05                        219.00      2,387.48
# 2002-11-22              180.83                        212.00      2,387.48
# 2002-11-25              175.14                        214.25      2,373.97
# 2002-11-26              168.02                        209.75      2,382.98
# 2002-11-27              171.58                        213.00      2,410.00
# 2002-11-28              177.63                        212.00      2,407.75
# 2002-11-29              173.71                        212.50      2,459.55
# 2002-12-02              176.21                        208.00      2,515.86
# 2002-12-03              169.80                        204.00      2,468.57
# 2002-12-04              172.29                        209.00      2,414.51
# 2002-12-05              167.31                        211.25      2,432.53
# 2002-12-06              166.59                        208.00      2,385.23
# 2002-12-09              163.03                        202.00      2,364.96
# 2002-12-10              163.39                        204.00      2,387.48
# 2002-12-11              166.95                        207.75      2,328.92
# 2002-12-12              163.75                        210.75      2,292.88
# 2002-12-13              160.19                        206.25      2,254.59
# 2002-12-16              165.53                        210.00      2,313.15
# 2002-12-17              160.90                        209.00      2,331.17
# 2002-12-18              156.98                        204.00      2,297.39
# 2002-12-19              158.41                        206.50      2,281.62
# 2002-12-20              161.61                        209.00      2,297.39
# 2002-12-23              163.75                        214.75      2,358.20
# 2002-12-24              163.03                        213.00      2,349.19
# 2002-12-25                 nan                           nan           nan
# 2002-12-26                 nan                           nan           nan
# 2002-12-27              157.69                        207.00      2,274.86
# 2002-12-30              160.19                        215.00      2,322.16
# 2002-12-31              161.25                        216.00      2,349.19
#
#             WPP PLC  UKX Index
# Date
# 2002-01-02   749.50   5,218.30
# 2002-01-03   769.00   5,318.80
# 2002-01-04   797.00   5,323.80
# 2002-01-07   809.00   5,293.60
# 2002-01-08   779.00   5,250.40
# 2002-01-09   758.00   5,228.50
# 2002-01-10   726.00   5,190.70
# 2002-01-11   736.50   5,198.60
# 2002-01-14   730.00   5,113.50
# 2002-01-15   740.00   5,166.00
# 2002-01-16   718.00   5,127.60
# 2002-01-17   715.00   5,138.40
# 2002-01-18   721.00   5,126.80
# 2002-01-21   710.00   5,138.50
# 2002-01-22   708.50   5,149.20
# 2002-01-23   676.00   5,180.60
# 2002-01-24   701.00   5,233.10
# 2002-01-25   699.00   5,193.00
# 2002-01-28   703.00   5,223.60
# 2002-01-29   690.00   5,131.40
# 2002-01-30   672.00   5,089.30
# 2002-01-31   690.00   5,164.80
# 2002-02-01   686.00   5,189.70
# 2002-02-04   664.50   5,167.30
# 2002-02-05   650.00   5,093.40
# 2002-02-06   650.00   5,073.80
# 2002-02-07   668.00   5,127.00
# 2002-02-08   705.00   5,128.10
# 2002-02-11   700.00   5,161.80
# 2002-02-12   679.00   5,135.70
# ...             ...        ...
# 2002-11-20   453.00   4,094.90
# 2002-11-21   497.00   4,190.00
# 2002-11-22   490.50   4,175.20
# 2002-11-25   484.75   4,122.20
# 2002-11-26   475.00   4,071.00
# 2002-11-27   505.00   4,144.20
# 2002-11-28   532.00   4,185.40
# 2002-11-29   544.50   4,169.40
# 2002-12-02   548.25   4,154.30
# 2002-12-03   525.00   4,075.40
# 2002-12-04   506.75   4,048.60
# 2002-12-05   498.75   4,032.40
# 2002-12-06   493.25   4,013.50
# 2002-12-09   483.00   3,933.90
# 2002-12-10   481.50   3,925.00
# 2002-12-11   488.50   3,974.90
# 2002-12-12   479.00   3,935.30
# 2002-12-13   465.25   3,878.10
# 2002-12-16   477.50   3,984.00
# 2002-12-17   461.25   3,908.70
# 2002-12-18   452.25   3,835.20
# 2002-12-19   469.25   3,841.40
# 2002-12-20   469.00   3,889.90
# 2002-12-23   471.50   3,936.90
# 2002-12-24   475.50   3,942.10
# 2002-12-25      nan        nan
# 2002-12-26      nan        nan
# 2002-12-27   457.00   3,829.40
# 2002-12-30   467.00   3,900.60
# 2002-12-31   474.50   3,940.40
#
# [260 rows x 99 columns]

# %%
pick.icm[universe[str(i-2)]].loc[str(years[i-2])][1:]

# %%
start = time.time()
#import data_to_pickle # Used to import data and read into pickles
# Read pickles
import read_pickle as pick
import functions as func

# Organisation of data
# Here, I organise all the stock prices into the possible investment universes. 
# This is done by constructing a dictionary

### A
universe = {}
for i in range(0,len(pick.investmentuniverse.columns)):
    universe [str(i)] = pick.investmentuniverse[pick.investmentuniverse.columns[i]].dropna() 
    # Dropna to filter out any missing values

Portfolios = {}
years = []
for i in range (2002, 2016+1):
    years.append(i)
for i in range (2, 17):
    Portfolios [str(i)] = pick.icm[universe[str(i-2)]].loc[str(years[i-2])][1:]
    
# Dividends
dividends_quarterly = pick.dividends.resample('Q').sum()

# Python file with construction of portfolios
import ICM296_portfolioconstruction as pc # pc = portfolio_constructor

# Risk-free rate
rf = pick.rf
rf = rf.iloc[:509]
rf = rf / 100
rf['IUMAJNB'] = rf['IUMAJNB'].map(lambda x: np.log((1+ x * (91/365.25))**(30.4375/91) ))
rf = rf * 100
rf.columns = rf.columns.map(lambda x: x + str(' (%)'))

rf.head()
rf.plot()
# Out:
# Index(['United Utilities Group PLC', 'Scottish Power Ltd', 'EMI Group Ltd',
#        'RSA Insurance Group PLC', 'Powergen Ltd', 'Lattice Group Ltd',
#        'Imperial Chemical Industries Ltd', 'Old Mutual PLC',
#        'Dixons Retail Group Ltd', 'Gallaher Group Ltd'],
#       dtype='object')
#             IUMAJNB (%)
# Dates
# 1975-01-31         0.84
# 1975-02-28         0.80
# 1975-03-31         0.77
# 1975-04-30         0.76
# 1975-05-31         0.78

# %% [markdown]
# # Regressions

# %% [markdown]
# ## Data Prep

# %%
Benchmark = pick.icm['UKX Index'].copy()

# %%
Benchmark.head()
# Out:
# Date
# 2000-01-03        nan
# 2000-01-04   6,665.90
# 2000-01-05   6,535.90
# 2000-01-06   6,447.20
# 2000-01-07   6,504.80
# Name: UKX Index, dtype: float64

# %%
Benchmark = Benchmark.fillna(method = 'bfill')
Benchmark = Benchmark.pct_change(1)+1
Benchmark = Benchmark.iloc[1:]
Benchmark = np.log(Benchmark)*100
Benchmark = Benchmark.resample('M').sum()
Benchmark = Benchmark['2002':'2016']

df = pick.df
df['Dates'] = pd.DatetimeIndex(freq = 'M', start='2002', end = '2017')
df.set_index('Dates', inplace = True)
df = np.log(df)*100

df['FTSE 100'] = Benchmark  ### Index starts somewhere else, automatic merge

df.columns = ['DoD', 'FTSE 100']
df ['DoD - FTSE 100'] = df['DoD'] - df ['FTSE 100']
df[['PDoD', 'PFTSE 100']]  =  np.exp(df[['DoD','FTSE 100']]/100)
df['PPDoD'] = func.valuecalculator(df['PDoD'])[1:]
Benchmark_value = func.valuecalculator(np.exp(Benchmark/100))[1:]
df['PPFTSE 100'] = Benchmark_value
df.columns = ['DoD (%)', 'FTSE 100 (%)', 
              'DoD - FTSE 100 (%)', 'PDoD', 
              'PFTSE 100', 'PPDoD', 'PPFTSE 100']
df ['Risk-Free Rate (%)'] = rf.loc['2001-12-30':'2016',:].shift(1).iloc[1:] 
# Risk-free rate is shifted one month forward to reflect that the rate is for the next month 

df.tail()
# Out:
# 'The portfolio's initial value:  10000
# 'The portfolio's initial value:  10000
#             DoD (%)  FTSE 100 (%)  DoD - FTSE 100 (%)  PDoD  PFTSE 100  \
# Dates
# 2016-08-31     1.59          0.85                0.74  1.02       1.01
# 2016-09-30     6.14          1.72                4.42  1.06       1.02
# 2016-10-31     5.87          0.79                5.08  1.06       1.01
# 2016-11-30    -1.29         -2.48                1.19  0.99       0.98
# 2016-12-31     4.35          5.16               -0.81  1.04       1.05
#
#                PPDoD  PPFTSE 100  Risk-Free Rate (%)
# Dates
# 2016-08-31 37,071.19   12,997.87                0.03
# 2016-09-30 39,418.41   13,223.69                0.02
# 2016-10-31 41,802.39   13,328.90                0.02
# 2016-11-30 41,264.86   13,002.24                0.01
# 2016-12-31 43,100.37   13,690.40                0.01

# %% [markdown]
# ## Data prep

# %%
fama = pick.fama
fama.set_index(pd.DatetimeIndex(freq = 'M', start='1980-10', end = '2016-7'), inplace = True)
fama = fama.loc['2002':,:]
fama ['DoD-Rf'] = (df.loc[:'2016-6','DoD (%)'] / 100) - (df.loc[:'2016-6','Risk-Free Rate (%)'] / 100)
fama ['Rm-Rf'] = (df.loc[:'2016-6','FTSE 100 (%)'] / 100) - (df.loc[:'2016-6','Risk-Free Rate (%)'] / 100)
fama = fama.loc[:,['DoD-Rf','Rm-Rf','SMB','HML', 'UMD']] ## regress returns on returns - returns on right
                                                         ## potentially explained by associated risks 

fama.head()
# Out:
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             DoD-Rf  Rm-Rf   SMB   HML  UMD
# 2002-01-31   -0.01  -0.01 -0.00 -0.05 0.11
# 2002-02-28   -0.03  -0.02 -0.02 -0.03 0.09
# 2002-03-31    0.06   0.03  0.01  0.03 0.01
# 2002-04-30   -0.01  -0.02  0.05  0.01 0.06
# 2002-05-31    0.01  -0.02  0.02  0.03 0.06

# %% [markdown]
# ## CAPM

# %%
## trying to explain the returns in the asset
## regressing on DoD-Rf

ydata = fama.loc[:,'DoD-Rf']
xdata = fama.loc[:,fama.columns[1]]
CAPM_results = sm.OLS(ydata, sm.add_constant(xdata)).fit()

print(CAPM_results.summary(yname = 'DoD Excess Returns'))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     DoD Excess Returns   R-squared:                       0.549
# Model:                            OLS   Adj. R-squared:                  0.546
# Method:                 Least Squares   F-statistic:                     209.1
# Date:                Sat, 21 Jul 2018   Prob (F-statistic):           1.58e-31
# Time:                        15:23:47   Log-Likelihood:                 338.30
# No. Observations:                 174   AIC:                            -672.6
# Df Residuals:                     172   BIC:                            -666.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0060      0.003      2.274      0.024       0.001       0.011
# Rm-Rf          0.9330      0.065     14.460      0.000       0.806       1.060
# ==============================================================================
# Omnibus:                       11.474   Durbin-Watson:                   2.120
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               28.557
# Skew:                          -0.046   Prob(JB):                     6.29e-07
# Kurtosis:                       4.982   Cond. No.                         24.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### CAPM Plot

# %%
plt.close('all')
sns.set(color_codes=True)
fama.to_clipboard()
### A regression plot draws a lindar relationship - 
ax = sns.regplot(xdata,ydata, scatter = True)
ax.set_facecolor('white')
ax.grid(False)
xaxis = ax.get_xlim()

## you would expect this to be self-calculating but you can just include the previous results 
ax.annotate('Regression line: y = {:.5f} +'
            '{:.3f}x\nR-Square: {:.4f}'.format(CAPM_results.params[0],
                                               CAPM_results.params[1],
                                               CAPM_results.rsquared),
            (xaxis[0],0.93*ax.get_ylim()[1]))

ax.set_ylim(top = ax.get_ylim()[1]*1.1)
plt.title('CAPM ', loc = 'left', fontweight = 'bold')

plt.axhline(y = 0, color = 'k', linewidth = 0.5)

savepath = ''
plt.savefig(savepath,transparent = True, dpi = 300, bbox_inches="tight");

# %% [markdown]
# ## Fama French

# %%
ydata = fama.loc[:,'DoD-Rf']
xdata = fama.loc[:,fama.columns[1:-1]]

FF_results = sm.OLS(ydata, sm.add_constant(xdata)).fit()
print(FF_results.summary(yname = 'DoD Excess Returns'));
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     DoD Excess Returns   R-squared:                       0.592
# Model:                            OLS   Adj. R-squared:                  0.584
# Method:                 Least Squares   F-statistic:                     82.11
# Date:                Sat, 21 Jul 2018   Prob (F-statistic):           6.94e-33
# Time:                        14:28:00   Log-Likelihood:                 347.01
# No. Observations:                 174   AIC:                            -686.0
# Df Residuals:                     170   BIC:                            -673.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0057      0.003      2.245      0.026       0.001       0.011
# Rm-Rf          0.8625      0.068     12.750      0.000       0.729       0.996
# SMB            0.2179      0.078      2.803      0.006       0.064       0.371
# HML            0.3003      0.113      2.669      0.008       0.078       0.522
# ==============================================================================
# Omnibus:                        7.201   Durbin-Watson:                   2.082
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):               12.483
# Skew:                          -0.068   Prob(JB):                      0.00195
# Kurtosis:                       4.305   Cond. No.                         46.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Carhart

# %%
ydata = fama.loc[:,'DoD-Rf']
xdata = fama.loc[:,fama.columns[1:]]

CAR_results = sm.OLS(ydata, sm.add_constant(xdata)).fit()
print(CAR_results.summary(yname = 'DoD Excess Returns'));
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     DoD Excess Returns   R-squared:                       0.628
# Model:                            OLS   Adj. R-squared:                  0.619
# Method:                 Least Squares   F-statistic:                     71.22
# Date:                Sat, 21 Jul 2018   Prob (F-statistic):           2.99e-35
# Time:                        14:28:04   Log-Likelihood:                 355.04
# No. Observations:                 174   AIC:                            -700.1
# Df Residuals:                     169   BIC:                            -684.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0081      0.002      3.238      0.001       0.003       0.013
# Rm-Rf          0.8385      0.065     12.889      0.000       0.710       0.967
# SMB            0.1335      0.077      1.726      0.086      -0.019       0.286
# HML            0.1278      0.116      1.103      0.272      -0.101       0.357
# UMD           -0.2444      0.060     -4.042      0.000      -0.364      -0.125
# ==============================================================================
# Omnibus:                       18.582   Durbin-Watson:                   2.140
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.268
# Skew:                          -0.545   Prob(JB):                     9.84e-08
# Kurtosis:                       4.807   Cond. No.                         50.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Risk Measures

# %% [markdown]
# ## Test Statistics

# %%
df.head()
# Out:
#             DoD (%)  FTSE 100 (%)  DoD - FTSE 100 (%)  PDoD  PFTSE 100  \
# Dates
# 2002-01-31    -0.32         -1.01                0.69  1.00       0.99
# 2002-02-28    -2.79         -1.24               -1.55  0.97       0.99
# 2002-03-31     6.22          2.91                3.31  1.06       1.03
# 2002-04-30    -0.32         -1.65                1.33  1.00       0.98
# 2002-05-31     1.32         -1.57                2.89  1.01       0.98
#
#                PPDoD  PPFTSE 100  Risk-Free Rate (%)
# Dates
# 2002-01-31  9,967.66    9,899.18                0.32
# 2002-02-28  9,693.31    9,776.90                0.32
# 2002-03-31 10,315.07   10,065.17                0.32
# 2002-04-30 10,282.46    9,900.72                0.33
# 2002-05-31 10,418.65    9,746.43                0.33

# %%
len(df)
# Out:
# 180

# %%
### Not Too Bad - Excess Volarility Does Seem to Play in Effect

series = df.loc[:,'DoD - FTSE 100 (%)']

d = series.mean()
s = series.std(ddof = 1)
n = np.sqrt(len((series)))

t = d/s*n

pval = stats.t.sf(np.abs(t), n**2-1)*2 # Must be two-sided as we're looking at <> 0

if pval <= 0.05:
    print('t-statistics = {:.2f}, P-value = {:.3f}'
          ' (Statistically significant)'.format(t, pval))
else:
    print('t-statistics = {:.2f}, P-value = {:.3f}'
          ' (Not statistically significant)'.format(t, pval))
# Out:
# t-statistics = 2.47, P-value = 0.014 (Statistically significant)

# %%
### Not Too Bad - Excess Volarility Does Seem to Play in Effect

series = df.loc[:,'DoD (%)'] - df.loc[:,'Risk-Free Rate (%)']

d = series.mean()
s = series.std(ddof = 1)
n = np.sqrt(len((series)))

t = d/s*n

pval = stats.t.sf(np.abs(t), n**2-1)*2 # Must be two-sided as we're looking at <> 0

if pval <= 0.05:
    print('t-statistics = {:.2f}, P-value = {:.3f}'
          ' (Statistically significant)'.format(t, pval))
else:
    print('t-statistics = {:.2f}, P-value = {:.3f}'
          ' (Not statistically significant)'.format(t, pval))
# Out:
# t-statistics = 1.63, P-value = 0.106 (Not statistically significant)

# %% [markdown]
# ## Maximum Drawdown

# %%
# A drawdown is a measurement of decline from an assets peak value to its 
# lowest point over a period of time. The drawdown is usually expressed as a 
# percentage from top to bottom. It can be measured on any asset including 
# individual stocks or sectors. However, it is most valuable as a measurement 
# of portfolio risk.
max_drawdownDoD = func.DD_measure(df['PPDoD'])
max_drawdownBench = func.DD_measure(df['PPFTSE 100'])
print("Max DoD drawdown is {:.2f}%".format(max_drawdownDoD))
print("Max benchmark drawdown is {:.2f}%".format(max_drawdownBench))
# Out:
# Max DoD drawdown is -51.66%
# Max benchmark drawdown is -43.02%

# %% [markdown]
# ## VaR and Expected Shortfall

# %%
VV = func.VaR (df.loc[:,'DoD (%)']) # Self-made function
VV.head()
VV.loc[:,['DoD (%)','Cumulative Weight']].where(VV['Cumulative Weight'] <= .05).dropna()
VV2 = func.VaR (df.loc[:,'FTSE 100 (%)'])
VV2.loc[:,['FTSE 100 (%)','Cumulative Weight']].where(VV2['Cumulative Weight'] <= .05).dropna()

print("The expected shortfall is: ",VV.loc[:,['DoD (%)']].where(VV['Cumulative Weight'] < .05).dropna().mean())
print("The expected shortfall is: ",VV2.loc[:,['FTSE 100 (%)']].
      where(VV2['Cumulative Weight'] < .05).dropna().mean())
# Out:
#             DoD (%)  Weights  Cumulative Weight
# Dates
# 2008-10-31   -20.54     0.01               0.01
# 2008-06-30   -15.96     0.01               0.01
# 2009-01-31   -14.12     0.01               0.02
# 2002-09-30   -11.04     0.01               0.02
# 2002-06-30   -10.16     0.01               0.03
#             DoD (%)  Cumulative Weight
# Dates
# 2008-10-31   -20.54               0.01
# 2008-06-30   -15.96               0.01
# 2009-01-31   -14.12               0.02
# 2002-09-30   -11.04               0.02
# 2002-06-30   -10.16               0.03
# 2003-01-31   -10.15               0.03
# 2008-09-30    -9.85               0.04
# 2009-02-28    -9.54               0.04
# 2008-01-31    -7.34               0.05
#             FTSE 100 (%)  Cumulative Weight
# Dates
# 2008-09-30        -13.95               0.01
# 2002-09-30        -12.74               0.01
# 2008-10-31        -11.33               0.02
# 2015-08-31        -10.01               0.02
# 2003-01-31         -9.94               0.03
# 2008-01-31         -9.36               0.03
# 2002-07-31         -9.22               0.04
# 2002-06-30         -8.81               0.04
# 2009-02-28         -8.01               0.05
# The expected shortfall is:  DoD (%)   -12.67
# dtype: float64
# The expected shortfall is:  FTSE 100 (%)   -10.67
# dtype: float64

# %% [markdown]
# ## Portfolio Turnover

# %%
lenght = len(np.unique(pick.DoDportfolios.values))
print("\n \nThe number of constituting companies in the DoD is: {}".format(lenght))
DoD = pick.DoDportfolios.copy()

turnover = [0]
for i in range(2002,2016):
    temp = []
    for item in DoD[i]:

        if item in str(DoD[i+1]):
            temp.append(1)
        else:
            temp.append(0)
    turnover.append((10-sum(temp))/10)

turnover_mean = np.mean(turnover[1:])  * 100 
transactioncost = 2*turnover_mean*0.01  ## 100 basis points two ways.

print('The average turnover in the period 2002 - 2016 '
      'is: {:.3f}%'.format(turnover_mean))
print('Therefore, turnover costs equates to: '
      '{:.2f}%'.format(transactioncost))

###A fund with a 35% turnover rate holds stocks for three years on average
###You can remove the transaction cost from the final value. 
###You can also calculate this value dynamically, with an increasing portfolio value, the current method
###Is more conservative
# Out:
#
# The number of constituting companies in the DoD is: 46
# The average turnover in the period 2002 - 2016 is: 35.000%
# Therefore, turnover costs equates to: 0.70%

# %% [markdown]
# ## Skewness and Kurtosis

# %%
# The bias = False is due to different normalizations. 
# Scipy by default does not correct for bias
skew = stats.skew(fama.loc[:,'DoD-Rf'], bias = False)
skew2 = stats.skew(fama.loc[:,'Rm-Rf'], bias = False)

kurt = stats.kurtosis(fama.loc[:,'DoD-Rf'], bias = False)
kurt2 = stats.kurtosis(fama.loc[:,'Rm-Rf'], bias = False)

print('\n(DoD), (FTSE 100)\n----------------------------'
      '\nSkew: ({:.4f}), ({:.4f})'
      '\nKurtosis: ({:.4f}), ({:.4f})'
      .format(skew, skew2,
             kurt, kurt2))
# Out:
# (DoD), (FTSE 100)
# ----------------------------
# Skew: (-0.3606), (-0.8017)
# Kurtosis: (3.1095), (1.1621)

# %% [markdown]
# ### Jarque-Bera

# %%
### This is a test for normality. 
### This test is focused on the skewness and kurtosis parameters

semi = (fama.loc[:,'DoD-Rf'])  # DoD portfolio excess returns
semi2 = fama.loc[:,'Rm-Rf'] # FTSE 100 excess returns

S = float(semi.shape[0]) / 6 * (skew**2 + 0.25*((kurt-3)**2)) # Test statistics
t = stats.chi2(2).ppf(0.95) # Threshold level
if S < t:
    print ("Not enough evidence to reject DoD as Normal "
           "according to the Jarque-Bera test. S = {:.4f} < {:.4f}".format(S,t))
else:
    print ("Reject that DoD is Normal according to "
           "the Jarque-Bera test; S = {:.4f} > {:.4f}".format(S,t))
    
S = float(semi2.shape[0]) / 6 * (skew2**2 + 0.25*((kurt2-3)**2)) # Test statistics
t = stats.chi2(2).ppf(0.95) # Threshold level
if S < t:
    print ("Not enough evidence to reject FTSE 100 as "
           "Normal according to the Jarque-Bera test. S = {:.4f} < {:.4f}".format(S,t))
else:
    print ("Reject that FTSE 100 is Normal according to the "
           "Jarque-Bera test; S = {:.4f} > {:.4f}".format(S,t))
# Out:
# Not enough evidence to reject DoD as Normal according to the Jarque-Bera test. S = 3.8571 < 5.9915
# Reject that FTSE 100 is Normal according to the Jarque-Bera test; S = 43.1304 > 5.9915

# %% [markdown]
# ## Corr, Variance, STD, SV and SSD

# %% [markdown]
# ### Correlation

# %%
fama.loc[:,fama.columns[:2]].corr()
fama.loc[:,fama.columns[:2]].cov()*12*100
# Out:
#         DoD-Rf  Rm-Rf
# DoD-Rf    1.00   0.74
# Rm-Rf     0.74   1.00
#         DoD-Rf  Rm-Rf
# DoD-Rf    3.21   1.89
# Rm-Rf     1.89   2.02

# %% [markdown]
# ### Variance

# %%
semi
# Out:
# 2002-01-31   -0.01
# 2002-02-28   -0.03
# 2002-03-31    0.06
# 2002-04-30   -0.01
# 2002-05-31    0.01
# 2002-06-30   -0.10
# 2002-07-31   -0.07
# 2002-08-31    0.00
# 2002-09-30   -0.11
# 2002-10-31    0.05
# 2002-11-30   -0.05
# 2002-12-31   -0.06
# 2003-01-31   -0.10
# 2003-02-28   -0.06
# 2003-03-31   -0.01
# 2003-04-30    0.14
# 2003-05-31    0.10
# 2003-06-30   -0.00
# 2003-07-31    0.05
# 2003-08-31    0.02
# 2003-09-30   -0.06
# 2003-10-31    0.07
# 2003-11-30    0.02
# 2003-12-31    0.02
# 2004-01-31    0.00
# 2004-02-29    0.07
# 2004-03-31   -0.02
# 2004-04-30    0.01
# 2004-05-31    0.01
# 2004-06-30    0.03
#               ...
# 2014-01-31    0.00
# 2014-02-28    0.01
# 2014-03-31   -0.02
# 2014-04-30    0.03
# 2014-05-31    0.03
# 2014-06-30   -0.02
# 2014-07-31    0.01
# 2014-08-31    0.01
# 2014-09-30   -0.03
# 2014-10-31    0.02
# 2014-11-30    0.04
# 2014-12-31   -0.01
# 2015-01-31    0.02
# 2015-02-28    0.02
# 2015-03-31   -0.02
# 2015-04-30    0.05
# 2015-05-31    0.01
# 2015-06-30   -0.06
# 2015-07-31    0.01
# 2015-08-31   -0.06
# 2015-09-30   -0.03
# 2015-10-31    0.04
# 2015-11-30   -0.01
# 2015-12-31   -0.02
# 2016-01-31   -0.04
# 2016-02-29    0.09
# 2016-03-31    0.05
# 2016-04-30    0.09
# 2016-05-31   -0.04
# 2016-06-30    0.09
# Freq: M, Name: DoD-Rf, Length: 174, dtype: float64

# %%
var = np.var(semi, ddof = 1)
var2 = np.var(semi2, ddof = 1)

std = np.std(semi, ddof = 1) * np.sqrt(12) * 100 ## Annualising Monthly Data: Putting in PercentagE Terms
std2 = np.std(semi2, ddof = 1) * np.sqrt(12) * 100

print('\n(DoD), (FTSE 100)\n----------------------------'
      '\nVariance: ({:.4f}), ({:.4f})'
      '\nStandard Deviation: ({:.4f}), ({:.4f}) *Figures are annualised'
      .format(var, var2,
             std, std2))
# Out:
# (DoD), (FTSE 100)
# ----------------------------
# Variance: (0.0027), (0.0017)
# Standard Deviation: (17.9055), (14.2155) *Figures are annualised

# %% [markdown]
# ### Semi-Variance and Semi-Standard Deviation

# %% [markdown]
# Semivariance is calculated by measuring the dispersion of all observations that fall below the mean or target value of a set of data. Not used that often because returns are generally symmetrical.

# %%
# Based on the LPM using the average excess return as minimal acceptable return, the 
# concepts of semi-variance (SV) and semi-standard
# deviation (SSD) can be calculated

threshold1 = np.mean(semi)
threshold2 = np.mean(semi2)

semi_variance1 = func.LPM(semi,threshold1,2) 
# This is for the DoD porfolio, using the mean as the threshold
semi_variance2 = func.LPM(semi2,threshold2,2) 
# This is for the FTSE 100 porfolio, using the mean as the threshold

Semi_std_DoD, Semi_std_Bench = np.sqrt(semi_variance1), np.sqrt(semi_variance2)

print("Semi-variance is {:.3f}% for DoD, and {:.3f}% for FTSE 100".
      format(semi_variance1*100,semi_variance2*100))
# Out:
# Semi-variance is 0.145% for DoD, and 0.102% for FTSE 100

# %% [markdown]
# ## Relative Risk Measures

# %%
DoD_excess_mean = fama.loc[:,'DoD-Rf'].mean()
Benchmark_excess_mean = fama.loc[:,'Rm-Rf'].mean()
DoD_excess_std = fama.loc[:,'DoD-Rf'].std(ddof = 1)
Benchmark_excess_std = fama.loc[:,'Rm-Rf'].std(ddof = 1)

# %% [markdown]
# ### Sharpe:

# %% [markdown]
# The Sharpe ratio (Lintner, 1965) measures the risk-adjusted performance of an asset over a risk-free alternative, where the total risk of the portfolio is expressed through its standard deviation. Despite its popularity and applicability since its origination, the SR has been proven to exhibit some unfortunate attributes. For instance, when excess return is negative, the reliability of the SR measure signicantly decreases

# %%
sharpeDoD, sharpeBench = [DoD_excess_mean / DoD_excess_std,
                          Benchmark_excess_mean / Benchmark_excess_std]
sharpeDoD, sharpeBench
# Out:
# (0.10361876602452838, -0.016965040248410876)

# %% [markdown]
# ### RAPA

# %% [markdown]
# Modigliani's Risk-Adjusted Performance Alternative Ratio (Modigliani and Modigliani, 1997) is derived from the Sharpe ratio, but it is more intuitive to interpret as it scales the ratio using the volatility of the benchmark - giving it its favourable attribute that it yields excess returns adjusted to its benchmark portfolio.

# %%
RAPA = DoD_excess_mean * Benchmark_excess_std / DoD_excess_std
RAPA
# Out:
# 0.004252166246767702

# %% [markdown]
# ### Treynor:

# %% [markdown]
# As the metric utilises the portfolio beta in its denominator, it focuses on the risk that cannot be diversied away. If the Treynor ratio is high, the manager is able to generate high returns per unit of market risk taken.

# %%
### Market Beta

TreynorDoD, TreynorBench = [DoD_excess_mean / CAR_results.params[1],
                            Benchmark_excess_mean / 1] 
# Beta from CARHART regression
TreynorDoD, TreynorBench
# Out:
# (0.006387429799909025, -0.0006961882898921215)

# %% [markdown]
# ### Sortino:

# %% [markdown]
# As previously mentioned in Section 4.2.1, Sortino and Price (1994) developed the Sortino ratio as a variant
# of Sharpe ratio, where the commonly used standard deviation metric in the denominator is replaced with
# semi-standard deviation that only quanties downside deviations.

# %%
SortinoDoD, SortinoBench = [DoD_excess_mean / Semi_std_DoD, 
                            Benchmark_excess_mean / Semi_std_Bench]
SortinoDoD, SortinoBench
# Out:
# (0.14042640703350256, -0.021774097067781936)

# %% [markdown]
# ### Probability of Shortfall and Return on Probability of Shortfall

# %% [markdown]
# The probability that daily returns is below the mean returns.

# %%
return_on_probability_shortfallDoD
# Out:
# 0.011163562645147593

# %%
prob_of_shortfallDoD = func.LPM(semi, threshold1,0)
prob_of_shortfallBench = func.LPM(semi2, threshold2,0)
return_on_probability_shortfallDoD = DoD_excess_mean / prob_of_shortfallDoD
return_on_probability_shortfallBench = Benchmark_excess_mean / prob_of_shortfallBench

# %% [markdown]
# ## Summary

# %% [markdown]
# While multiple definitions of the Sterling ratio exist, it measures return over average drawdown, versus the more commonly used max drawdown. Burke does the same but this time calculates the return over the square root of the max drawdown.

# %%
## I would like to include, average and median annual drawdowns. 

#%% Arithmetic returns
test = pd.DataFrame(df.loc[:,df.columns[0]]/100)


test ['RF'] = rf.loc['2002':'2016','IUMAJNB (%)']/100
test = test.loc['2002':'2016-06',:]
mean1 = test.loc[:,test.columns[0]].mean()*12 * 100

mean2 = (test.loc[:,test.columns[0]] - test.loc[:,test.columns[1]]).mean()*12 * 100
std2 = (test.loc[:,test.columns[0]] - test.loc[:,test.columns[1]]).std(ddof = 1)*np.sqrt(12) * 100

print('Arithmetic mean: {:.2}%'
      '\nArithmetic excess mean: {:.2}%'.format(mean1, mean2))

SterlingDoD = DoD_excess_mean * 11.6 / (np.abs(max_drawdownDoD)/100)
SterlingBench = Benchmark_excess_mean * 11.6 / (np.abs(max_drawdownBench)/100)
BurkeDoD = DoD_excess_mean * 11.6 / (np.sqrt((np.abs(max_drawdownDoD)/100)))
BurkeBench = Benchmark_excess_mean * 11.6 / (np.sqrt((np.abs(max_drawdownBench)/100)))
print('\n\n--Summary of risk measures--'
      '\n---(DoD, FTSE 100)---'
      '\nSharpe ratios: {:.4f}, {:.4f}'
      '\n RAPA: {:.4f}\nTreynor ratios: {:.4f}, {:.4f}\nSortino ratios: {:.4f}, {:.4f}'
      '\nProbability of Shortfall: {:.2f}%, {:.2f}%\nReturn on Prob. of Shortfall: {:.4f}, {:.4f}'
      '\nSterling ratios: {:.4}, {:.4}\nBurke ratios: {:.4}, {:.4}'
      '\nMaximum Drawdown: {:.4}%, {:.4}%'
      '\n------------------------------------------'
      .format(sharpeDoD, sharpeBench, RAPA,  TreynorDoD,  TreynorBench,  
              SortinoDoD,  SortinoBench,  
              100*prob_of_shortfallDoD,  100*prob_of_shortfallBench, 
              return_on_probability_shortfallDoD, return_on_probability_shortfallBench, 
              SterlingDoD, SterlingBench, BurkeDoD, BurkeBench, 
              max_drawdownDoD, max_drawdownBench))
# Out:
# Arithmetic mean: 8.8%
# Arithmetic excess mean: 6.4%
#
#
# --Summary of risk measures--
# ---(DoD, FTSE 100)---
# Sharpe ratios: 0.1036, -0.0170
#  RAPA: 0.0043
# Treynor ratios: 0.0064, -0.0007
# Sortino ratios: 0.1404, -0.0218
# Probability of Shortfall: 47.98%, 46.24%
# Return on Prob. of Shortfall: 0.0112, -0.0015
# Sterling ratios: 0.1203, -0.01877
# Burke ratios: 0.08644, -0.01231
# Maximum Drawdown: -51.66%, -43.02%
# ------------------------------------------

# %% [markdown]
# # Plots

# %% [markdown]
# ## Portfolio values

# %%
plt.clf
plt.cla

df2 = df.loc['2002':'2016',['PPDoD','PPFTSE 100']].copy()
df2.plot(figsize=(10,5))
plt.title('Portfolio values', loc = 'left', fontweight = 'bold')
plt.ylabel('Value')

plt.xlabel('')

ax = plt.gca()
ax.legend(loc=2, fancybox=False, shadow=True, ncol=8)
ax.xaxis.grid(False)
ax.yaxis.grid(alpha = 0.8) # how visible is the lines

ax.axes.get_yaxis().set_major_formatter(
    FuncFormatter(lambda x, p: format(int(x), ',')))
ax.axes.set_facecolor('white')
# plt.figure(figsize=(20,10))

# Saving the figure
savepath = ''
plt.savefig(savepath,transparent = True, dpi = 300, bbox_inches="tight");

# %% [markdown]
# ## Bar plot for excess return

# %%
plt.clf
plt.cla
plt.close('all')

style.use('seaborn-pastel')
# Data to plot
xdata = df.index
ydata0 = df['DoD - FTSE 100 (%)']
# ydata1 = df['PPFTSE 100']
       
# Setting up the fig3ure environment
fig2 = plt.figure(figsize=(20,10))

# Defining the grid and adding plots
ax2 = plt.subplot2grid((1,1),(0,0), facecolor = 'white')
plt.subplots_adjust(left = 0.05, bottom = 0.1, right = .65, top = 0.95, wspace = 0.0, hspace = 0)

ax2.bar(xdata,ydata0, width=20, label = 'Difference')
# ax1.plot_date(xdata, ydata1, '-', label='FTSE 100')

# Plot title, x-label and y-label
plt.ylabel('Difference')
plt.title('DoD - FTSE 100 (%)', loc = 'left', fontweight="bold")

# Adjusting the tickers on x-axis and y-axis
fig2.autofmt_xdate(rotation=90) # To rotate x-ticks
ax2.xaxis.set_major_locator(mdates.YearLocator())

fmt = '%.0f%%' # Format you want the ticks, e.g. '40%'
yticks = mtick.FormatStrFormatter(fmt)
ax2.yaxis.set_major_formatter(yticks)


# Adjusting the legend box
# box = ax1.get_position()
# ax1.set_position([box.x0, box.y0 + box.height * 0.1,
#     box.width, box.height * 0.9])
# ax1.legend(loc='lower center', bbox_to_anchor=(0.5, 0),
#     fancybox=True, shadow=True, ncol=8)

# Adjusting the grids
ax2.xaxis.grid(False)
ax2.yaxis.grid(alpha = 1) # how visible is the lines

# plt.tight_layout()

# Saving the fig3ure
savepath = ''
plt.savefig(savepath,transparent = True, dpi = 200, bbox_inches="tight");

# %% [markdown]
# ## FTSE 100 Histogram

# %%
plt.clf
plt.cla
plt.close('all')
style.use('bmh')

# Data to plot
y = fama.loc[:,'Rm-Rf']

# n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75)
n, bins, patches = plt.hist(y, 20, normed=1, label = 'Distribution', rwidth=.75)
plt.axis([np.min(y)*1.2, np.max(y)*1.3, 0, np.max(n)*1.2])
ax = plt.gca()
ax.set_facecolor('white')
y = mlab.normpdf(bins, np.mean(y), np.std(y, ddof=1))
l = plt.plot(bins, y, 'r--', linewidth=1, label ='Best fit')

# Adjusting the grids
plt.grid(False)
ax.legend(loc = 'upper left')
# plt.tight_layout()
#plt.show() # Might not be necessary to display all the fig3ures

#Etc.
plt.xlabel('Excess return')
plt.title('Histogram of FTSE 100 Excess Return', loc = 'left', fontweight = 'bold')
 
# Saving the figure
savepath = ''
plt.savefig(savepath,transparent = True, dpi = 300, bbox_inches="tight");

# %% [markdown]
# ## DoD Histogram

# %%
plt.clf
plt.cla
plt.close('all')

# Data to plot
y = fama.loc[:,'DoD-Rf']

# n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75)
n, bins, patches = plt.hist(y, 20, normed=1, label = 'Distribution', rwidth=0.75)
plt.axis([np.min(y)*1.2, np.max(y)*1.3, 0, np.max(n)*1.2])
ax = plt.gca()
ax.set_facecolor('white')
y = mlab.normpdf(bins, np.mean(y), np.std(y, ddof=1))
l = plt.plot(bins, y, 'r--', linewidth=1, label = 'Best fit')

# Adjusting the grids
plt.grid(False)

ax.legend(loc = 'upper left')
# plt.tight_layout()
#Etc.
plt.xlabel('Excess return')
plt.title('Histogram of DoD Excess Return', loc = 'left', fontweight = 'bold')

# Saving the fig3ure
savepath = ''
plt.savefig(savepath,transparent = True, dpi = 300, bbox_inches="tight");

# %% [markdown]
# ## Rolling STD

# %%
plt.clf
plt.cla
plt.close('all')
style.use('bmh')

# Data to plot
xdata = fama.index
ydata0 = fama['DoD-Rf'].rolling(3).std()
ydata1 = fama['DoD-Rf'].rolling(6).std()
ydata2 = fama['DoD-Rf'].rolling(12).std()    

# Setting up the figure environment
fig5 = plt.figure(figsize=(20,10))

# Defining the grid and adding plots
ax5 = plt.subplot2grid((1,1),(0,0),facecolor='white')
plt.subplots_adjust(left = 0.05, bottom = 0.1, right = .65, top = 0.95, wspace = 0.0, hspace = 0)

ax5.plot_date(xdata, ydata0, '-', label='3-month STD')
ax5.plot_date(xdata, ydata1, '-', label='6-month STD')
ax5.plot_date(xdata, ydata2, '-', label='12-month STD')

plt.plot((np.min(fama.index), np.max(fama.index)), (DoD_excess_std, DoD_excess_std), '--', label ='Constant STD')
plt.plot((np.min(fama.index), np.max(fama.index)), 
         (np.sqrt(semi_variance1), np.sqrt(semi_variance1)), '-.', label ='Constant semi-STD')

# Plot title, x-label and y-label
plt.title('Rolling Standard Deviation', loc = 'left', fontweight = 'bold')

# Adjusting the tickers on x-axis and y-axis
fig5.autofmt_xdate(rotation=90)
ax5.xaxis.set_major_locator(mdates.YearLocator())

# Adjusting the legend box

# Adjusting the grids
ax5.xaxis.grid(False)
ax5.yaxis.grid(alpha = 0) # how visible is the lines

ax5.legend(fontsize = 'large')
ax5.tick_params(axis='x', labelsize=15)
ax5.tick_params(axis='y', labelsize=15)


plt.ylim((0,np.max(ydata0)*1.1))
plt.xlim((xdata.min(), xdata.max()))
# Saving the figure
savepath = ""
plt.savefig(savepath,transparent = True, dpi = 300, bbox_inches="tight");

# %% [markdown]
# ## Rolling std2

# %%
plt.clf
plt.cla
plt.close('all')
style.use('bmh')

# Data to plot
xdata = df.index
ydata0 = (df.loc[:,df.columns[0]]/100).rolling(3).std(ddof = 1)
ydata1 = (df.loc[:,df.columns[1]]/100).rolling(3).std(ddof = 1)
      
# Setting up the figure environment
fig2 = plt.figure(figsize=(20,10))

# Defining the grid and adding plots
ax2 = plt.subplot2grid((1,1),(0,0),facecolor='white')
plt.subplots_adjust(left = 0.05, bottom = 0.1, right = .65, top = 0.95, wspace = 0.0, hspace = 0)

ax2.plot_date(xdata, ydata0, '-', label='DoD 3-month Rolling STD')
ax2.plot_date(xdata, ydata1, '-', label='FTSE 100 3-month Rolling STD')

# Plot title, x-label and y-label
# plt.ylabel('Value')
plt.title('Rolling Standard Deviation', loc = 'left', fontweight = 'bold')

# Adjusting the tickers on x-axis and y-axis
fig2.autofmt_xdate(rotation=90)
ax2.xaxis.set_major_locator(mdates.YearLocator())

# Adjusting the grids
ax2.xaxis.grid(False)
ax2.yaxis.grid(alpha = 0) # how visible is the lines

ax2.legend(fontsize = 'large')
ax2.tick_params(axis='x', labelsize=15)
ax2.tick_params(axis='y', labelsize=15)


plt.ylim((0, np.max(ydata0)*1.1))

# Saving the figure
savepath = ''
plt.savefig(savepath, transparent = True, dpi = 300, bbox_inches= "tight");

# %% [markdown]
# ## Max Drawdown plot

# %%
plt.clf
plt.cla
plt.close('all')

style.use('fivethirtyeight')

# Data to plot
xdata = df.index
ydata0 = df['PPDoD']
       
# Setting up the figure environment
fig7 = plt.figure(figsize=(20,10))

# Defining the grid and adding plots
ax7 = plt.subplot2grid((1,1),(0,0),facecolor='white')
plt.subplots_adjust(left = 0.05, bottom = 0.1, right = .65, top = 0.95, wspace = 0.0, hspace = 0)

ax7.plot_date(xdata, ydata0, '-', label='DoD Portfolio Value')
plt.plot(('2007-10-31', '2009-02-28'), (df['PPDoD']['2007':'2009'].max(), df['PPDoD']['2007':'2009'].min()), '-', label = 'Max Drawdown Period')
plt.plot(('2007-10-31', '2009-02-28'), (df['PPDoD']['2007':'2009'].min(), df['PPDoD']['2007':'2009'].min()), 'r--')
plt.plot(('2007-10-31', '2007-10-31'), (df['PPDoD']['2007':'2009'].max(), df['PPDoD']['2007':'2009'].min()), 'r--')

# Plot title, x-label and y-label
plt.ylabel('Portfolio Value')
plt.title('Maximum\nDrawdown', loc = 'left', fontweight = 'bold')

# Adjusting the tickers on x-axis and y-axis
fig7.autofmt_xdate(rotation=90)
ax7.xaxis.set_major_locator(mdates.YearLocator())
ax7.axes.get_yaxis().set_major_formatter(
        FuncFormatter(lambda x, p: format(int(x), ',')))

# Adjusting the grids
ax7.xaxis.grid(False)
ax7.yaxis.grid(alpha = 0) # how visible is the lines
ax7.tick_params(axis='x', labelsize=15)
ax7.tick_params(axis='y', labelsize=15)
ax7.legend(loc = 2,fontsize = 'medium')

plt.ylim((0,np.max(ydata0)*1.1))

# Saving the figure
savepath = ''
plt.savefig(savepath,transparent = True, dpi = 300, bbox_inches="tight");

# %%
end = time.time()

print('-------------------------------------'
      '\n{:.4f} seconds used to load script'
      '\n-------------------------------------'
      .format(end-start));
# Out:
# -------------------------------------
# 270.4966 seconds used to load script
# -------------------------------------

# %% [markdown]
# Monthly:
#
# Advantages – Fast to compute, easier to model, easier to identify changes in trends, better for strategic long term forecasting.
#
# But, The primary benefit of using monthly returns data instead of daily return data is that with monthly data, returns are at least approximately normally distributed
