# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pprint import pprint
sns.set(style="whitegrid", color_codes=True)
# %matplotlib inline

# %%
data = pd.read_csv('/home/artem/Projects/wolf_of_crunchbase/data/data.csv')

# %% [markdown]
# <H3>Columns in data file</H3>

# %% [markdown]
# | Variable             | Definition                                               | Key           |
# |----------------------|----------------------------------------------------------|---------------|
# | company_id           | Company ID                                               |               |
# | category_code        | Company category                                         |               |
# | country_code         | Country                                                  | USA, NZL, other|
# | state_code           | State                                                    | California, other |
# | ipo                  | IPO                                                      | True or False |
# | is_acquired          | Company is acquired or not                               | True or False |
# | is_closed            | Company is closed or not                                 | True or False |
# | age                  | Company age in days                                      |               |
# | mba_degree           | Number of people with MBA degree associated with company |               |
# | phd_degree           | Number of people with PhD degree associated with company |               |
# | ms_degree            | Number of people with MS degree associated with company  |               |
# | other_degree         | Number of other people associated with company           |               |
# | offices              | Number of company's offices                              |               |
# | average_funded       | Funds per round                                          |               |
# | average_participants | Participants per round                                   |               |
# | total_rounds         | Total number of rounds                                   |               |
# | products_number      | Total number of products                                 |               |
# | acquired_companies   | Total number of acquired companies                       |               |

# %%
print("Total companies: ", data.shape[0])
print("Total features: ", data.shape[1])
print("Share of acquired companies: ", data.is_acquired.mean())
# Out:
# Total companies:  31984
# Total features:  18
# Share of acquired companies:  0.0822911455728

# %% [markdown]
# <H3>Testing data assumption</H3>

# %% [markdown]
# Columns 'age' and 'category_code' seem as important features. Let's test this assumption.

# %% [markdown]
# <H4>Probability of company acquisition depending on age (splitting by five years)</H4>
# Also count of companies of each age is located below.

# %%
age_acquisition = pd.DataFrame({'age': data.age.apply(lambda x: x // (365 * 5))})
age_acquisition['is_acquired'] = data.is_acquired
fig, axs = plt.subplots(2, 1, figsize=(15,15))
sns.barplot(x='age', y='is_acquired', data=age_acquisition, ax=axs[0])
sns.countplot(x='age', data=age_acquisition[age_acquisition['age'].notnull()], ax=axs[1])

# %% [markdown]
# As we can see, there is some mistakes in data: age of several companies is negative. Let's rid off it.

# %%
data = data[data.age >= 0 | data.age.isnull()]
age_acquisition = pd.DataFrame({'age': data.age.apply(lambda x: x // (365 * 5))})
age_acquisition['is_acquired'] = data.is_acquired
fig, axs = plt.subplots(2, 1, figsize=(15,15))
sns.barplot(x='age', y='is_acquired', data=age_acquisition, ax=axs[0])
sns.countplot(x='age', data=age_acquisition[age_acquisition['age'].notnull()], ax=axs[1])

# %% [markdown]
# It seems like probability of company acquisition grows up till second decade of company life and falls after reaching it.

# %% [markdown]
# <H4>Probability of company acquisition depending on company category</H4>

# %%
fig, axs = plt.subplots(2, 1, figsize=(15,15))
p1 = sns.barplot(x='category_code', y='is_acquired', data=data, ax=axs[0])
p2 = sns.countplot(x='category_code', data=data, ax=axs[1])
for plot in [p1, p2]:
    for item in plot.get_xticklabels():
        item.set_rotation(90)

# %%
data.groupby(by='category_code').is_acquired.mean().sort_values(ascending=False)
# Out:
# category_code
# network_hosting     0.179104
# semiconductor       0.178363
# public_relations    0.146667
# security            0.126126
# web                 0.124541
# software            0.110281
# enterprise          0.108696
# search              0.107527
# advertising         0.106047
# mobile              0.097162
# messaging           0.095477
# games_video         0.092046
# news                0.089820
# travel              0.083744
# hardware            0.062580
# music               0.062500
# photo_video         0.062500
# other               0.062099
# analytics           0.056761
# cleantech           0.053517
# ecommerce           0.051957
# biotech             0.048889
# design              0.047619
# transportation      0.042857
# consulting          0.041825
# finance             0.038554
# fashion             0.034314
# social              0.034156
# automotive          0.027778
# health              0.026258
# education           0.026190
# medical             0.024887
# legal               0.019608
# sports              0.018519
# real_estate         0.015873
# manufacturing       0.014423
# hospitality         0.014218
# government          0.000000
# local               0.000000
# nanotech            0.000000
# nonprofit           0.000000
# pets                0.000000
# Name: is_acquired, dtype: float64

# %% [markdown]
# Based on data shown above we can conclude that companes of certain categories can be acquired with higher probability than others.

# %% [markdown]
# <H4>Correlation between columns</H4>

# %%
corrmat = data[data.dtypes[data.dtypes == np.float64].index].corr()
corrmat
# Out:
#                       average_funded  average_participants  products_number  \
# average_funded              1.000000              0.050979         0.071589
# average_participants        0.050979              1.000000        -0.003777
# products_number             0.071589             -0.003777         1.000000
# offices                     0.021502              0.031578         0.449413
# acquired_companies          0.125772             -0.043033         0.679108
# mba_degree                  0.182240              0.022222         0.575789
# phd_degree                  0.130939              0.011802         0.825573
# ms_degree                   0.113740              0.001408         0.695036
# other_degree                0.128026              0.052782         0.574770
# age                         0.167126             -0.009220         0.148596
#
#                        offices  acquired_companies  mba_degree  phd_degree  \
# average_funded        0.021502            0.125772    0.182240    0.130939
# average_participants  0.031578           -0.043033    0.022222    0.011802
# products_number       0.449413            0.679108    0.575789    0.825573
# offices               1.000000            0.367855    0.313248    0.409808
# acquired_companies    0.367855            1.000000    0.858100    0.796597
# mba_degree            0.313248            0.858100    1.000000    0.684928
# phd_degree            0.409808            0.796597    0.684928    1.000000
# ms_degree             0.425208            0.898303    0.873886    0.737951
# other_degree          0.342800            0.879960    0.939978    0.730530
# age                   0.015777            0.117737    0.158387    0.163349
#
#                       ms_degree  other_degree       age
# average_funded         0.113740      0.128026  0.167126
# average_participants   0.001408      0.052782 -0.009220
# products_number        0.695036      0.574770  0.148596
# offices                0.425208      0.342800  0.015777
# acquired_companies     0.898303      0.879960  0.117737
# mba_degree             0.873886      0.939978  0.158387
# phd_degree             0.737951      0.730530  0.163349
# ms_degree              1.000000      0.918635  0.154711
# other_degree           0.918635      1.000000  0.157485
# age                    0.154711      0.157485  1.000000

# %%
f, ax = plt.subplots(figsize=(14, 11))
sns.heatmap(corrmat, vmax=1, square=True);

# %% [markdown]
# It is obvious that degree columns will correlate with each other, because they relate with general concept "number of people". Also there is no questions why number of products correlate with number of people and acquired companies.

# %% [markdown]
# <H4> Pairwise data distribution</H4>

# %%
economic_columns = ['average_funded', 'average_participants', 'total_rounds', 'offices', 
                    'products_number', 'acquired_companies']
columns = economic_columns + ['is_acquired']
investment_info = data[data[columns].notnull().all(axis=1)][columns]
sns.pairplot(investment_info, hue='is_acquired')

# %% [markdown]
# It is difficult to say something concrete about data distribution based on pairplot shown above, but it seems like companies got acquired have less economic succesfullness.

# %% [markdown]
# <H3>Fullness of columns</H3>

# %%
data.notnull().mean()
# Out:
# company_id              1.000000
# category_code           0.980412
# country_code            1.000000
# state_code              1.000000
# average_funded          0.888961
# total_rounds            1.000000
# average_participants    1.000000
# products_number         0.152663
# offices                 0.953765
# acquired_companies      0.054601
# mba_degree              0.285982
# phd_degree              0.094634
# ms_degree               0.217099
# other_degree            0.532381
# ipo                     1.000000
# is_acquired             1.000000
# is_closed               1.000000
# age                     1.000000
# dtype: float64
