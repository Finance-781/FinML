# %% [markdown]
# # Basics
# **In this tutorial you will become familiar with the core concepts of python.**
#
# The following skills/competenecies are essential for a financial machine learning engineer:
#
# 1. Knowing some programming languages like stata, sas, python, R or SQL. For this course, you would only need to learn how to use **python** as it is becoming the dominant langauge of the day. If you want to work in industry, I would also recommend learning some SQL.
# 1. Basic Statistics: Computationally applying the knowledge of math and statistics you already have like mean, median or standard deviation calculations.
# 1. Data Munging: Working with messy and difficult data. Like fixing inconsistent date and string formatting. As you guess, **python** helps us.
# 1. Data Visualization: We will visualize the data with **python** libraries like matplot and seaborn will be used.
# 1. Machine Learning (ML): You do not need to understand all the math behind the machine learning techniques, but it might help you in your future endevours. You do need to know when and where to use what machine learning implementation and be able to compare the advantages and disadvantages of different approaches.
# 1. Jupyter Notebooks: Although you can learn how to used Jupyter Notebooks (Lab) as you go along, I strongly recommend checking out some youtube videos like this https://www.youtube.com/watch?v=HW29067qVWk

# %%
from IPython.display import HTML
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/HW29067qVWk" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/HW29067qVWk" frameborder="0" allow="autoplay; encrypted-media" allowfullscreen></iframe>

# %% [markdown]
# ### First Becoming a Financial Data Scientist  !!!
#
# **Content:**
# 1. [Introduction to Python:](#1)
#     1. [Matplotlib](#2)
#     1. [Dictionaries ](#3)
#     1. [Pandas](#4)
#     1. [Logic, control flow and filtering](#5)
#     1. [Loop data structures](#6)
# 1. [Python Data Science Toolbox:](#7)
#     1. [User defined function](#8)
#     1. [Scope](#9)
#     1. [Nested function](#10)
#     1. [Default and flexible arguments](#11)
#     1. [Lambda function](#12)
#     1. [Anonymous function](#13)
#     1. [Iterators](#14)
#     1. [List comprehension](#15)
# 1. [Cleaning Data](#16)
#     1. [Diagnose data for cleaning](#17)
#     1. [Exploratory data analysis](#18)
#     1. [Visual exploratory data analysis](#19)
#     1. [Tidy data](#20)
#     1. [Pivoting data](#21)
#     1. [Concatenating data](#22)
#     1. [Data types](#23)
#     1. [Missing data and testing with assert](#24)
# 1. [Pandas Foundation](#25)
#     1. [Review of pandas](#26)
#     1. [Building data frames from scratch](#27)
#     1. [Visual exploratory data analysis](#28)
#     1. [Statistical explatory data analysis](#29)
#     1. [Indexing pandas time series](#30)
#     1. [Resampling pandas time series](#31)
# 1. [Manipulating Data Frames with Pandas](#32)
#     1. [Indexing data frames](#33)
#     1. [Slicing data frames](#34)
#     1. [Filtering data frames](#35)
#     1. [Transforming data frames](#36)
#     1. [Index objects and labeled data](#37)
#     1. [Hierarchical indexing](#38)
#     1. [Pivoting data frames](#39)
#     1. [Stacking and unstacking data frames](#40)
#     1. [Melting data frames](#41)
#     1. [Categoricals and groupby](#42)

# %% [markdown]
# ## Preintroduction

# %%
1+1
# Out:
# 2

# %%
value = 2/4
value
# Out:
# 0.5

# %%
name = "Hello World"
name
# Out:
# 'Hello World'

# %%
print(name)
# Out:
# Hello World

# %%
## First error 
value + name
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-b8cbd91a149b> in <module>()
#       1 ## First error
# ----> 2 value + name
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %% [markdown]
# Although your textbook is a good source of machine learning implementation code, often times the simple code gets overlooked, google and many sites like stackoverflow will be your friend.

# %% [raw]
# Possible Google Searches
#
# TypeError:
# TypeError: unsupported operand
# TypeError: unsupported operand type(s) for +
# TypeError: unsupported operand type(s) for +: 'float'
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %% [markdown]
# TypeError: unsupported operand type(s) for +
#
# ![alt text](figures/Google.png)
#
# #### Solution
#
# ![alt text](figures/Stack.png)

# %%
combination = str(value) + " " +  name; combination    # You can print in the same line by adding ;variable_name at the end
# Out:
# '0.5 Hello World'

# %%
## or use the traditional way
combination = str(value) + " " +  name
combination
# Out:
# '0.5 Hello World'

# %% [markdown]
# ### First Description of Data

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool

# %%
## This is simply a bit of importing logic that you don't have ..
## .. to concern yourself with for now. 

from pathlib import Path

github_p = "https://github.com/firmai/FinML/blob/master/Lecture%201%20-%20Python%20Basics/"

my_file = Path("data/pokemon.csv") # Defines path
if my_file.is_file():              # See if file exists
    print("Local file found")      
    data = pd.read_csv('data/pokemon.csv')
else:
    print("Be patient: loading from github")
    data = pd.read_csv(github_p+'data/pokemon.csv')
# Out:
# Local file found

# %%
data_copy = data.copy()  ## keeping a clean copy of the dataframe for later use

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %% [markdown]
# <br>We can use the describe() method. The describe method includes:
# * count: number of entries
# * mean: average of entries
# * std: standart deviation
# * min: minimum entry
# * 25%: first quantile
# * 50%: median or second quantile
# * 75%: third quantile
# * max: maximum entry

# %%
data.describe()
# Out:
#               #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %%
data.corr()
# Out:
#                    #        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# #           1.000000  0.097712  0.102664  0.094691  0.089199  0.085596
# HP          0.097712  1.000000  0.422386  0.239622  0.362380  0.378718
# Attack      0.102664  0.422386  1.000000  0.438687  0.396362  0.263990
# Defense     0.094691  0.239622  0.438687  1.000000  0.223549  0.510747
# Sp. Atk     0.089199  0.362380  0.396362  0.223549  1.000000  0.506121
# Sp. Def     0.085596  0.378718  0.263990  0.510747  0.506121  1.000000
# Speed       0.012181  0.175952  0.381240  0.015227  0.473018  0.259133
# Generation  0.983428  0.058683  0.051451  0.042419  0.036437  0.028486
# Legendary   0.154336  0.273620  0.345408  0.246377  0.448907  0.363937
#
#                Speed  Generation  Legendary
# #           0.012181    0.983428   0.154336
# HP          0.175952    0.058683   0.273620
# Attack      0.381240    0.051451   0.345408
# Defense     0.015227    0.042419   0.246377
# ...

# %%
#correlation map
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
data.head(10)
# Out:
#     #              Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   1         Bulbasaur  Grass  Poison  45      49       49       65       65
# 1   2           Ivysaur  Grass  Poison  60      62       63       80       80
# 2   3          Venusaur  Grass  Poison  80      82       83      100      100
# 3   4     Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4   5        Charmander   Fire     NaN  39      52       43       60       50
# 5   6        Charmeleon   Fire     NaN  58      64       58       80       65
# 6   7         Charizard   Fire  Flying  78      84       78      109       85
# 7   8  Mega Charizard X   Fire  Dragon  78     130      111      130       85
# 8   9  Mega Charizard Y   Fire  Flying  78     104       78      159      115
# 9  10          Squirtle  Water     NaN  44      48       65       50       64
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# ...

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# <a id="1"></a> <br>
# # 1. INTRODUCTION TO PYTHON

# %% [markdown]
# <a id="2"></a> <br>
# ### MATPLOTLIB
# Matplot is a python library that help us to plot data. The easiest and basic plots are line, scatter and histogram plots.
# * Line plots are better presented when the x-axis is time.
# * Scatter plots appear better when there is correlation between two variables
# * Histogram are used to investigate the distribution of numerical data.
# * Customization: Colors, labels, thickness of line, title, opacity, grid, figsize, ticks of axis and linestyle

# %%
data.head(2)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary
# 0           1      False
# 1           1      False

# %% [markdown]
# Don't worry about the below code, we will deal with plots later, this is purely to try and identify some trends in the data.

# %%
# Line Plot
# color = color, label = label, linewidth = width of line, alpha = opacity, grid = grid, linestyle = style of line
data.Speed.plot(kind = 'line', color = 'g',label = 'Speed',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
data.Defense.plot(color = 'r',label = 'Defense',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('Index value')         # xlabel = unspecified so simply the index value
plt.ylabel('Value')               # ylabel = here we use the value attributal to the feature (Speed, Defence). 
plt.title('Speed and Defence Accross Pokémon')            # title =  title of plot
plt.show()

# %%
# Scatter Plot 
# x = attack, y = defense
data.plot(kind='scatter', x='Attack', y='Defense',alpha = 0.5,color = 'red')
plt.xlabel('Attack')                                # label = name of label
plt.ylabel('Defence')
plt.title('Attack Defense Scatter Plot')            # title = title of plot
plt.show()

# %%
# Histogram
# bins = number of bar in figure
data.Speed.plot(kind = 'hist',bins = 50,figsize = (12,12))  ## specifify bins for level of granularity
plt.show()

# %%
# clf() = cleans it up again you can start a fresh
data.Speed.plot(kind = 'hist',bins = 50)
plt.clf()
# We cannot see plot due to clf()

# %% [markdown]
# <a id="3"></a> <br>
# ### DICTIONARY
# Why we need a dictionary?
# * It has 'key' and 'value'
# * Faster than lists
# <br>
# What is a key and a value. Example:
# * dictionary = {'spain' : 'madrid'}
# * Key is spain.
# * Values is madrid.
# <br>
# <br>**It's that easy.**
# <br>Lets practice some other properties like keys(), values(), update, add, check, remove key, remove all entries and remove dicrionary.

# %%
#create dictionary and look its keys and values

dictionary = {'spain' : 'madrid','usa' : 'vegas'} # we define dictionaries with squiggly brackets
print(dictionary.keys())
print(dictionary.values())
# Out:
# dict_keys(['spain', 'usa'])
# dict_values(['madrid', 'vegas'])

# %%
# Keys are unique

dictionary['spain'] = "barcelona"    # update existing entry
print(dictionary)
dictionary['france'] = "paris"       # Add new entry
print(dictionary)
del dictionary['spain']              # remove entry with key 'spain'
print(dictionary)
print('france' in dictionary)        # check include or not
dictionary.clear()                   # remove all entries in dict
print(dictionary)
# Out:
# {'spain': 'barcelona', 'usa': 'vegas'}
# {'spain': 'barcelona', 'usa': 'vegas', 'france': 'paris'}
# {'usa': 'vegas', 'france': 'paris'}
# True
# {}

# %% [markdown]
# <a id="4"></a> <br>
# ### PANDAS
# What we need to know about pandas?
# * CSV: comma - separated values

# %%
data = pd.read_csv('data/pokemon.csv')  # this creates a dataframe (df) called data

# %%
## Creating a series and a new dataframe

series = data['Defense']                # data['Defense'] = series
print(type(series))                     # type() to identify the class type in python

data_frame = data[['Defense','Speed']]  # data[['Defense','Speed']] = dataframe
print(type(data_frame))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# <a id="5"></a> <br>
# Before continue with pandas,   we need to learn **logic, control flow** and **filtering.**
# <br>Comparison operator:  ==, <, >, <=
# <br>Boolean operators: and, or ,not
# <br> Filtering pandas

# %%
# Comparison operator
print(3 > 2)
print(3!=2)
# Boolean operators
print(True and False)
print(True or False)
# Out:
# True
# True
# False
# True

# %%
# 1 - Filtering Pandas data frame
x = data['Defense']>200     # There are only 3 pokemons who have higher defense value than 200
data[x]                     # Only select those for who Defense >200 is true
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 230  231       Shuckle    Bug    Rock  20      10      230       10      230
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 230      5           2      False
# 333     50           3      False

# %% [markdown]
# ![alt text](figures/Poke.png)

# %%
# 2 - Filtering pandas with logical_and
# There are only 2 pokemons who have higher defence value than 200 and higher attack value than 100
data[(data['Defense']>200)&(data['Attack']>100 )] # & is the logical And
# Out:
#        #          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 224  225  Mega Steelix  Steel  Ground  75     125      230       55       95
# 333  334   Mega Aggron  Steel     NaN  70     140      230       60       80
#
#      Speed  Generation  Legendary
# 224     30           2      False
# 333     50           3      False

# %% [markdown]
# <a id="6"></a> <br>
# ### WHILE and FOR LOOPS
# We will learn most basic while and for loops

# %%
# Stay in loop if condition( i is not equal 5) is true
i = 0
while i != 5 :
    print('i is: ',i)
    i +=1 
print(i,' is equal to 5')
# Out:
# i is:  0
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# 5  is equal to 5

# %%
# Stay in loop if condition( i is not equal 5) is true
lis = [1,2,3,4,5]
for i in lis:
    print('i is: ',i)
print('')
# Out:
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# i is:  5

# %%
# Enumerate creates an integer iterator 
lis = ["aa","bb","cc","dd","ee"]

for index, value in enumerate(lis):
    print(index)       # integer iterator
    print(value)       # value from list iterator
    print(lis[index])  # using integer iterator as index for list
# Out:
# 0
# aa
# aa
# 1
# bb
# bb
# 2
# cc
# cc
# 3
# dd
# dd
# 4
# ee
# ee

# %%
# For pandas we can cycle though index and value with iterros()
for index,value in data[['Attack']][0:3].iterrows():
    print(index," : ",value)
# Out:
# 0  :  Attack    49
# Name: 0, dtype: int64
# 1  :  Attack    62
# Name: 1, dtype: int64
# 2  :  Attack    82
# Name: 2, dtype: int64

# %%
## Note above, this is how you can obtain a slection from for example 0 - 5
data[['Attack']][0:5]
# Out:
#    Attack
# 0      49
# 1      62
# 2      82
# 3     100
# 4      52

# %% [markdown]
# <a id="7"></a> <br>
# # 2. PYTHON DATA SCIENCE TOOLBOX

# %% [markdown]
# <a id="8"></a> <br>
# ### USER DEFINED FUNCTION
#
# The user essentially creates a small program that they can use throughout the code instead of copying and pasting

# %%
# example of what we learn above
def list_ex():
    t = [1,2,3]   ## this is a list 
    return t
a = list_ex(); a
# Out:
# [1, 2, 3]

# %% [markdown]
# <a id="16"></a> <br>
# # 3.CLEANING DATA

# %% [markdown]
# <a id="17"></a> <br>
# ### DIAGNOSE DATA for CLEANING
# We need to diagnose and clean data before exploring. This is just a short section, more to come in the
# dataprocessing module
# <br>Unclean data:
# * Column name inconsistency like upper-lower case letter or space between words
# * Missing data
# * Formatting issues
#
#
# <br> We will use head, tail, columns, shape and info methods to diagnose data

# %%
data.head()  # head shows first 5 rows
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
# tail shows last 5 rows
data.tail()
# Out:
#        #            Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  796         Diancie     Rock  Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock  Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic  Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic   Dark  80     160       60      170
# 799  800       Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
# columns gives column names of features
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# shape gives number of rows and columns in a tuble
data.shape
# Out:
# (800, 12)

# %%
# For example lets look frequency of pokemom types
print(data['Type 1'].value_counts(dropna =False))  # if there are nan values that also be counted
# As it can be seen below there are 112 water pokemon or 70 grass pokemon
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
# <a id="19"></a> <br>
# ### VISUAL EXPLORATORY DATA ANALYSIS
# * Box plots: visualize basic statistics like outliers, min/max or quantiles

# %%
# For example: compare attack of pokemons that are legendary and not legendary

data.boxplot(column='Attack',by = 'Legendary')
plt.show()

# %% [markdown]
# <a id="22"></a> <br>
# ### CONCATENATING DATA
# We can concatenate two dataframe

# %%
# Firstly lets create 2 data frame
data1 = data.head()
data2= data.tail()
conc_data_row = pd.concat([data1,data2],axis =0,ignore_index =True) # axis = 0 : concatanates dataframes in row
conc_data_row
# Out:
#      #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0    1       Bulbasaur    Grass  Poison  45      49       49       65
# 1    2         Ivysaur    Grass  Poison  60      62       63       80
# 2    3        Venusaur    Grass  Poison  80      82       83      100
# 3    4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4    5      Charmander     Fire     NaN  39      52       43       60
# 5  796         Diancie     Rock   Fairy  50     100      150      100
# 6  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 7  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 8  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 9  800       Volcanion     Fire   Water  80     110      120      130
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# ...

# %%
data1 = data[['Attack',"Speed","Sp. Atk"]].head()
data2= data[["Generation","Legendary","Speed"]].head()
conc_data_col = pd.concat([data1,data2],axis =1) # axis = 1 : concatanates dataframes by column
conc_data_col
# Out:
#    Attack  Speed  Sp. Atk  Generation  Legendary  Speed
# 0      49     45       65           1      False     45
# 1      62     60       80           1      False     60
# 2      82     80      100           1      False     80
# 3     100     80      122           1      False     80
# 4      52     65       60           1      False     65

# %% [markdown]
# <a id="23"></a> <br>
# ### DATA TYPES
# There are 5 basic data types: object(string),booleab,  integer, float and categorical.
# <br> We can make conversion data types like from str to categorical or from int to float
# <br> Why is category important:
# * make dataframe smaller in memory
# * can be utilised for anlaysis especially for sklear(we will learn later)

# %%
data.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
# lets convert object(str) to categorical and int to float.
data['Type 1'] = data['Type 1'].astype('category')   ## .astype() helps you to convert a series
data['Speed'] = data['Speed'].astype('float')

# %%
# As you can see Type 1 is converted from object to categorical
# And Speed ,s converted from int to float
data.dtypes
# Out:
# #                int64
# Name            object
# Type 1        category
# Type 2          object
# HP               int64
# Attack           int64
# Defense          int64
# Sp. Atk          int64
# Sp. Def          int64
# Speed          float64
# Generation       int64
# Legendary         bool
# dtype: object

# %% [markdown]
# <a id="24"></a> <br>
# ### MISSING DATA and TESTING WITH ASSERT
# If we encounter with missing data, what we can do:
# * leave as is
# * drop them with dropna()
# * fill missing value with fillna()
# * fill missing values with test statistics like mean
# <br>Assert statement: check that you can turn on or turn off when you are done with your testing of the program

# %%
# Lets look at does pokemon data have nan value
# As you can see there are 800 entries. However Type 2 has 414 non-null object so it has 386 null object.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          799 non-null object
# Type 1        800 non-null category
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null float64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), category(1), float64(1), int64(7), object(2)
# memory usage: 64.9+ KB

# %%
# Lets chech Type 2
data["Type 2"].value_counts(dropna =False)
# As you can see, there are 386 NAN values
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ice          14
# Ghost        14
# Rock         14
# Water        14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
# Lets drop nan (remove null) values
data_drop = data.copy()   ## assign a new dataframe, you don't have to use copy, but best to do so for future purpose. 
data_drop["Type 2"].dropna(inplace = True)  # inplace = True means we do not assign it to new variable. Changes automatically assigned to data
# So does it work ?

# %% [markdown]
# <a id="25"></a> <br>
# # 4. PANDAS FOUNDATION

# %% [markdown]
# <a id="26"></a> <br>
# ### REVİEW of PANDAS
#
#
# * single column = series
# * NaN = not a number
# * dataframe.values = numpy

# %% [markdown]
# <a id="27"></a> <br>
# ### BUILDING DATA FRAMES FROM SCRATCH
# * We can build data frames from csv as we did earlier.
# * Also we can build dataframe from dictionaries
#     * zip() method: This function returns a list of tuples, where the i-th tuple contains the i-th element from each of the argument sequences or iterables.
# * We can add a new column
# * Broadcasting: Create a new column and assign a value to entire column

# %%
## You would almost never have to create a dictionary by hand to load
## ..into a pandas dataframe, but here is an example for the off chance

# data frames from dictionary
country = ["Spain","France"]
population = ["11","12"]
list_label = ["country","population"]
list_col = [country,population]
zipped = list(zip(list_label,list_col))
data_dict = dict(zipped)

print (data_dict)
df = pd.DataFrame(data_dict)  ## you can load a dictionary into a pandas df
df
# Out:
# {'country': ['Spain', 'France'], 'population': ['11', '12']}
#   country population
# 0   Spain         11
# 1  France         12

# %%
# Add new columns
df["capital"] = ["madrid","paris"]
df
# Out:
#   country population capital
# 0   Spain         11  madrid
# 1  France         12   paris

# %%
# Broadcasting
df["income"] = 0 #Broadcasting entire column
df
# Out:
#   country population capital  income
# 0   Spain         11  madrid       0
# 1  France         12   paris       0

# %% [markdown]
# <a id="28"></a> <br>
# ### VISUAL EXPLORATORY DATA ANALYSIS
# * Plot
# * Subplot
# * Histogram:
#     * bins: number of bins
#     * range(tuble): min and max values of bins
#     * normed(boolean): normalize or not
#     * cumulative(boolean): compute cumulative distribution

# %%
# Plotting all data 
data1 = data.loc[:,["Attack","Defense","Speed"]]
data1.plot()
# it is confusing

# %%
# subplots
data1.plot(subplots = True)
plt.show()

# %%
# scatter plot  
data1.plot(kind = "scatter",x="Attack",y = "Defense")
plt.show()

# %%
# hist plot  
data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),normed = True)

# %%
# histogram subplot with non cumulative and cumulative
fig, axes = plt.subplots(nrows=2,ncols=1)
data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),normed = True,ax = axes[0])
data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),normed = True,ax = axes[1],cumulative = True)
plt.savefig('graph.png')
plt.show()

# %% [markdown]
# <a id="30"></a> <br>
# ### INDEXING PANDAS TIME SERIES
# * This is important for financial time series
# * datetime = object
# * parse_dates(boolean): Transform date to ISO 8601 (yyyy-mm-dd hh:mm:ss ) format

# %%
# remove warning
import warnings
warnings.filterwarnings("ignore")

# Lets practice creating dates and setting it as the index
data2 = data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object
# lets make date as index
data2= data2.set_index("date")
data2
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-01-10  1      Bulbasaur  Grass  Poison  45      49       49       65
# 1992-02-10  2        Ivysaur  Grass  Poison  60      62       63       80
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-01-10       65   45.0           1      False
# 1992-02-10       80   60.0           1      False
# 1992-03-10      100   80.0           1      False
# 1993-03-15      120   80.0           1      False
# 1993-03-16       50   65.0           1      False

# %%
# Now we can select according to our date index
data2.loc["1993-03-16"]
# Out:
# #                      5
# Name          Charmander
# Type 1              Fire
# Type 2               NaN
# HP                    39
# Attack                52
# Defense               43
# Sp. Atk               60
# Sp. Def               50
# Speed                 65
# Generation             1
# Legendary          False
# Name: 1993-03-16 00:00:00, dtype: object

# %%
# Here we select a range of dates
data2.loc["1992-03-10":"1993-03-16"]
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-03-10      100   80.0           1      False
# 1993-03-15      120   80.0           1      False
# 1993-03-16       50   65.0           1      False

# %% [markdown]
# <a id="31"></a> <br>
# ### RESAMPLING PANDAS TIME SERIES
# * Resampling: statistical method over different time intervals
#     * Needs string to specify frequency like "M" = month or "A" = year
# * Downsampling: reduce date time rows to longer frequency like from daily to weekly
# * Upsampling: increase date time rows to shorter frequency like from daily to hourly
# * Interpolate: Interpolate values according to different methods like ‘linear’, ‘time’ or index’
#     * https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.interpolate.html

# %%
data2.head()
# Out:
#             #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# date
# 1992-01-10  1      Bulbasaur  Grass  Poison  45      49       49       65
# 1992-02-10  2        Ivysaur  Grass  Poison  60      62       63       80
# 1992-03-10  3       Venusaur  Grass  Poison  80      82       83      100
# 1993-03-15  4  Mega Venusaur  Grass  Poison  80     100      123      122
# 1993-03-16  5     Charmander   Fire     NaN  39      52       43       60
#
#             Sp. Def  Speed  Generation  Legendary
# date
# 1992-01-10       65   45.0           1      False
# 1992-02-10       80   60.0           1      False
# 1992-03-10      100   80.0           1      False
# 1993-03-15      120   80.0           1      False
# 1993-03-16       50   65.0           1      False

# %%
# We will use data2 that we create at previous part
data2.resample("A").mean()    # Annual Resampling
# Out:
#               #         HP     Attack  Defense    Sp. Atk    Sp. Def  \
# date
# 1992-12-31  2.0  61.666667  64.333333     65.0  81.666667  81.666667
# 1993-12-31  4.5  59.500000  76.000000     83.0  91.000000  85.000000
#
#                 Speed  Generation  Legendary
# date
# 1992-12-31  61.666667         1.0      False
# 1993-12-31  72.500000         1.0      False

# %%
# Lets resample with month
data2.resample("M").mean()
# As you can see there are a lot of nan because data2 does not include all months
# Out:
#               #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# date
# 1992-01-31  1.0  45.0    49.0     49.0     65.0     65.0   45.0         1.0
# 1992-02-29  2.0  60.0    62.0     63.0     80.0     80.0   60.0         1.0
# 1992-03-31  3.0  80.0    82.0     83.0    100.0    100.0   80.0         1.0
# 1992-04-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-05-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-06-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-07-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-08-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-09-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-10-31  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# 1992-11-30  NaN   NaN     NaN      NaN      NaN      NaN    NaN         NaN
# ...

# %%
# In real life (data is real. Not created from us like data2) we can solve this problem with interpolate
# We can interpolete from first value
data2.resample("M").first().interpolate("linear")
# Out:
#                    #           Name Type 1  Type 2    HP  Attack     Defense  \
# date
# 1992-01-31  1.000000      Bulbasaur  Grass  Poison  45.0    49.0   49.000000
# 1992-02-29  2.000000        Ivysaur  Grass  Poison  60.0    62.0   63.000000
# 1992-03-31  3.000000       Venusaur  Grass  Poison  80.0    82.0   83.000000
# 1992-04-30  3.083333            NaN    NaN     NaN  80.0    83.5   86.333333
# 1992-05-31  3.166667            NaN    NaN     NaN  80.0    85.0   89.666667
# 1992-06-30  3.250000            NaN    NaN     NaN  80.0    86.5   93.000000
# 1992-07-31  3.333333            NaN    NaN     NaN  80.0    88.0   96.333333
# 1992-08-31  3.416667            NaN    NaN     NaN  80.0    89.5   99.666667
# 1992-09-30  3.500000            NaN    NaN     NaN  80.0    91.0  103.000000
# 1992-10-31  3.583333            NaN    NaN     NaN  80.0    92.5  106.333333
# 1992-11-30  3.666667            NaN    NaN     NaN  80.0    94.0  109.666667
# ...

# %%
# Or we can interpolate with mean()
data2.resample("M").mean().interpolate("linear")
# Out:
#                 #         HP  Attack  Defense  Sp. Atk  Sp. Def   Speed  \
# date
# 1992-01-31  1.000  45.000000    49.0     49.0    65.00    65.00  45.000
# 1992-02-29  2.000  60.000000    62.0     63.0    80.00    80.00  60.000
# 1992-03-31  3.000  80.000000    82.0     83.0   100.00   100.00  80.000
# 1992-04-30  3.125  78.291667    81.5     83.0    99.25    98.75  79.375
# 1992-05-31  3.250  76.583333    81.0     83.0    98.50    97.50  78.750
# 1992-06-30  3.375  74.875000    80.5     83.0    97.75    96.25  78.125
# 1992-07-31  3.500  73.166667    80.0     83.0    97.00    95.00  77.500
# 1992-08-31  3.625  71.458333    79.5     83.0    96.25    93.75  76.875
# 1992-09-30  3.750  69.750000    79.0     83.0    95.50    92.50  76.250
# 1992-10-31  3.875  68.041667    78.5     83.0    94.75    91.25  75.625
# 1992-11-30  4.000  66.333333    78.0     83.0    94.00    90.00  75.000
# 1992-12-31  4.125  64.625000    77.5     83.0    93.25    88.75  74.375
# ...

# %% [markdown]
# <a id="32"></a> <br>
# # MANIPULATING DATA FRAMES WITH PANDAS

# %% [markdown]
# <a id="33"></a> <br>
# ### INDEXING DATA FRAMES
# * Indexing using square brackets
# * Using column attribute and row label
# * Using loc accessor
# * Selecting only some columns

# %%
# read data
data = data_copy.copy()
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
# indexing using square brackets
data["HP"][0]
# Out:
# 45

# %%
# using column attribute and row label
data.HP[0]
# Out:
# 45

# %%
# using loc accessor
data.loc[0,["HP"]]
# Out:
# HP    45
# Name: 0, dtype: object

# %%
# Selecting only some columns
data[["HP","Attack"]][:5]
# Out:
#    HP  Attack
# 0  45      49
# 1  60      62
# 2  80      82
# 3  80     100
# 4  39      52

# %% [markdown]
# <a id="36"></a> <br>
# ### TRANSFORMING DATA
# * Plain python functions
# * Lambda function: to apply arbitrary python function to every element
# * Defining column using other columns

# %%
# Apply plain python functions to series
def div(n):
    return n/2

data["HP"].apply(div)[:10]  ## Or you can write..
                            ## data.HP.apply(div)[:10]
# Out:
# 0    22.5
# 1    30.0
# 2    40.0
# 3    40.0
# 4    19.5
# 5    29.0
# 6    39.0
# 7    39.0
# 8    39.0
# 9    22.0
# Name: HP, dtype: float64

# %%
# Or we can use lambda function
data.HP.apply(lambda n : n/2)[:10]
# Out:
# 0    22.5
# 1    30.0
# 2    40.0
# 3    40.0
# 4    19.5
# 5    29.0
# 6    39.0
# 7    39.0
# 8    39.0
# 9    22.0
# Name: HP, dtype: float64

# %%
# Defining column using other columns
data["total_power"] = data.Attack + data.Defense
data.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary  total_power
# 0     45           1      False           98
# 1     60           1      False          125
# 2     80           1      False          165
# 3     80           1      False          223
# 4     65           1      False           95

# %%
## A few more things to do
data["Power to Speed"] = data["total_power"]/data["Speed"]
data["Power to Speed_log"] = np.log(data["Power to Speed"])
data["HP"] = data["HP"]*100
data["Legendary_integer"] = data["Legendary"].apply(lambda x: 1 if x==True else 0 )

# %%
data.head(2)
# Out:
#    #       Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison  4500      49       49       65       65
# 1  2    Ivysaur  Grass  Poison  6000      62       63       80       80
#
#    Speed  Generation  Legendary  total_power  Power to Speed  \
# 0     45           1      False           98        2.177778
# 1     60           1      False          125        2.083333
#
#    Power to Speed_log  Legendary_integer
# 0            0.778305                  0
# 1            0.733969                  0

# %% [markdown]
# <a id="37"></a> <br>
# ### INDEX OBJECTS AND LABELED DATA
# index: sequence of label

# %%
## another way of doing is, is setting it equal to instead of using inplace
data3 = data.copy()
data3 = data3.reset_index(drop="True") # reset index and drop the previous index instead of creating an
                                             # .. extra column for it
data3.head(2)
# Out:
#    #       Name Type 1  Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1  Bulbasaur  Grass  Poison  4500      49       49       65       65
# 1  2    Ivysaur  Grass  Poison  6000      62       63       80       80
#
#    Speed  Generation  Legendary  total_power  Power to Speed  \
# 0     45           1      False           98        2.177778
# 1     60           1      False          125        2.083333
#
#    Power to Speed_log  Legendary_integer
# 0            0.778305                  0
# 1            0.733969                  0

# %%
## remember we have a command to set the index, lets set it to the names 
data3= data.copy()
data3= data3.set_index("Name")
data3.head(2)
## you can also use data.index = data["Name"]
# Out:
#            # Type 1  Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Name
# Bulbasaur  1  Grass  Poison  4500      49       49       65       65     45
# Ivysaur    2  Grass  Poison  6000      62       63       80       80     60
#
#            Generation  Legendary  total_power  Power to Speed  \
# Name
# Bulbasaur           1      False           98        2.177778
# Ivysaur             1      False          125        2.083333
#
#            Power to Speed_log  Legendary_integer
# Name
# Bulbasaur            0.778305                  0
# Ivysaur              0.733969                  0

# %% [markdown]
# <a id="38"></a> <br>
# ### HIERARCHICAL INDEXING
# * Setting indexing

# %%
# You can also set a multi-index, I would discourage its use and instead combine two columns to create one unique
# ..id for an index, multi-index, isn't necessary here as we already have a unique pokemon name
data1 = data.dropna(subset=["Type 2"])
data1 = data1.set_index(["Type 1","Type 2"]) 
data1.head(10)
# data1.loc["Fire","Flying"] # howw to use indexes
# Out:
#                 #              Name    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1 Type 2
# Grass  Poison   1         Bulbasaur  4500      49       49       65       65
#        Poison   2           Ivysaur  6000      62       63       80       80
#        Poison   3          Venusaur  8000      82       83      100      100
#        Poison   4     Mega Venusaur  8000     100      123      122      120
# Fire   Flying   7         Charizard  7800      84       78      109       85
#        Dragon   8  Mega Charizard X  7800     130      111      130       85
#        Flying   9  Mega Charizard Y  7800     104       78      159      115
# Bug    Flying  16        Butterfree  6000      45       50       90       80
#        Poison  17            Weedle  4000      35       30       20       20
#        Poison  18            Kakuna  4500      25       50       25       25
#
#                Speed  Generation  Legendary  total_power  Power to Speed  \
# Type 1 Type 2
# ...

# %% [markdown]
# <a id="42"></a> <br>
# ### CATEGORICALS AND GROUPBY

# %%
# We will use df
df
# Out:
#   country population capital  income
# 0   Spain         11  madrid       0
# 1  France         12   paris       0

# %%
# according to treatment take means of other features, mean is an aggregation / reduction method
data.groupby("Type 1").mean()    # there are other methods like sum, std,max or min
# Out:
#                    #           HP      Attack     Defense    Sp. Atk  \
# Type 1
# Bug       369.072464  5688.405797   70.971014   70.724638  53.869565
# Dark      508.387097  6680.645161   88.387097   70.225806  74.645161
# Dragon    522.843750  8331.250000  112.125000   86.375000  96.843750
# Electric  401.590909  5979.545455   69.090909   66.295455  90.022727
# Fairy     495.529412  7411.764706   61.529412   65.705882  78.529412
# Fighting  401.444444  6985.185185   96.777778   65.925926  53.111111
# Fire      361.942308  6990.384615   84.769231   67.769231  88.980769
# Flying    747.500000  7075.000000   78.750000   66.250000  94.250000
# Ghost     537.281250  6443.750000   73.781250   81.187500  79.343750
# Grass     381.414286  6727.142857   73.214286   70.800000  77.500000
# Ground    393.312500  7378.125000   95.750000   84.843750  56.468750
# Ice       466.666667  7200.000000   72.750000   71.416667  77.541667
# ...

# %%
# we can only choose one of the feature
data.groupby("Type 1").max()["HP"]
# Out:
# Type 1
# Bug          8600
# Dark        12600
# Dragon      12500
# Electric     9000
# Fairy       12600
# Fighting    14400
# Fire        11500
# Flying       8500
# Ghost       15000
# Grass       12300
# Ground      11500
# Ice         11000
# Normal      25500
# Poison      10500
# Psychic     19000
# Rock        12300
# Steel       10000
# Water       17000
# Name: HP, dtype: int64

# %% [markdown]
# ### Libraries
# There are a number of built in libraries that extend what Python can do.

# %%
import random
random.seed(0)
random.random()
# Out:
# 0.8444218515250481

# %%
import math
math.cos(math.pi)
# Out:
# -1.0

# %%
import sympy  # symbolic mathematics
x = sympy.symbols('x')
sympy.diff(x ** 2, x)
# Out:
# 2*x

# %%
import numpy  # Fast numeric computations
A = numpy.matrix([[0, 2], [1, 2]])
B = numpy.matrix([[3, 1], [1, -2]])
A * B
# Out:
# matrix([[ 2, -4],
#         [ 5, -3]])

# %% [markdown]
# There are also a number of libraries outside of anaconda that are also very powerful. Some examples include:
#
#     Ciw: modeling of queues;
#     Axelrod: game theory.
#     tqdm: adding progress bars to your code :)
#     The list is very large...
#
# To install these libraries from the internet you can open a command prompt (Windows) or a terminal (Mac OSX) and type:
#
# `pip install <library-name>`
